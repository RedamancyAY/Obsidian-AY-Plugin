# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from copy import deepcopy

from tools import (
    CROSS_LANGUAGE_TASKCLASSES,
    DisplayCrossMethodEvaluation,
    DisplayInnerEvaluation,
)

# %%
V = list(range(11))
V.remove(5)


MODELs_VERSIONS = {
    "LCNN": V,
    "RawNet2": V,
    "RawGAT": V,
    "Wave2Vec2": V,
    "Wave2Vec2-old1": V,
    "WaveLM": V,
    "WaveLM-old1": V,
    "LibriSeVoc": V,
    "AudioClip": V,
    "Wav2Clip": V,
    "AASIST": V,
    "SFATNet": V,
    "ASDG": V,
    "Ours/ResNet": V,
}

# %% [markdown]
# # Inner evaluation

# %%
_MODELs_VERSIONS = deepcopy(MODELs_VERSIONS)
_MODELs_VERSIONS.update({})
models = list(MODELs_VERSIONS.keys())
versions = list(MODELs_VERSIONS.values())

# %%
tasks = ["LibriSeVoc_inner", "wavefake_inner", "DECRO_english", "DECRO_chinese"]
res = DisplayInnerEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=True)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawGAT/wavefake_inner/version_10/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_inner/version_6/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_inner/version_7/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_inner/version_8/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_inner/version_9/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_inner/version_10/test.csv
# task           LibriSeVoc_inner wavefake_inner DECRO_english DECRO_chinese  \
# model
# LCNN                 99.96/0.90     99.98/0.64    99.96/0.90    99.88/1.43
# RawNet2              95.00/6.94     97.93/6.95    99.37/3.68    99.32/3.85
# RawGAT               99.89/1.45     99.92/1.25    99.89/1.45    99.87/1.56
# Wave2Vec2           64.53/39.08    54.05/46.99   84.63/17.97   66.54/35.41
# Wave2Vec2-old1      100.00/0.09     99.99/0.44    99.99/0.47    99.98/0.43
# WaveLM               96.57/3.97    63.60/37.32    99.99/0.33    96.06/4.54
# WaveLM-old1         100.00/0.03    100.00/0.26    99.98/0.55    99.99/0.41
# LibriSeVoc           99.44/2.86     99.37/3.93    99.42/3.42    99.10/4.36
# AudioClip            99.32/3.98     99.92/1.29    99.88/0.91    99.58/2.85
# Wav2Clip             99.83/1.60     99.99/0.30    99.98/0.68    99.21/4.08
# AASIST               99.91/1.33     99.84/1.60    99.91/1.35    99.56/2.92
# SFATNet              98.33/5.95     99.89/1.52    99.85/1.75    97.50/8.17
# ASDG                 99.93/1.22     99.94/0.77    99.92/1.10    99.80/1.76
# Ours/ResNet          99.98/0.47    100.00/0.07    99.99/0.46    99.99/0.45
#
# task                    avg
# model
# LCNN             99.94/0.97
# RawNet2          97.91/5.36
# RawGAT           99.89/1.43
# Wave2Vec2       67.44/34.86
# Wave2Vec2-old1   99.99/0.35
# WaveLM          89.06/11.54
# WaveLM-old1      99.99/0.31
# LibriSeVoc       99.33/3.64
# AudioClip        99.67/2.26
# Wav2Clip         99.75/1.66
# AASIST           99.81/1.80
# SFATNet          98.89/4.35
# ASDG             99.90/1.21
# Ours/ResNet      99.99/0.36

# %%
tasks = ["LibriSeVoc_inner", "wavefake_inner", "DECRO_english", "DECRO_chinese"]
res = DisplayInnerEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=False)
res.display(show_latex=0).to_csv("inner.csv")
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawGAT/wavefake_inner/version_10/test.csv

# %% [markdown]
# ## Cross method

# %% [markdown]
# - "Ours/ablations/con_loss_voc/ResNet": seed 0
# - "Ours/ablations/con_loss_feat_voc/ResNet": seed 0

# %%
_MODELs_VERSIONS = deepcopy(MODELs_VERSIONS)
_MODELs_VERSIONS.update({
    # "Ours/ResNet": range(20),
})
models = list(_MODELs_VERSIONS.keys())
versions = list(_MODELs_VERSIONS.values())

# %%
tasks = ["LibriSeVoc_cross_method"]

res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=True)
res.display(show_latex=0)
# Out:
# task            LibriSeVoc_cross_method                            \
# method                                1                         2
# model
# LCNN            97.52/$\phantom{0}$7.93               69.18/36.43
# RawNet2                     74.63/31.35               78.26/28.13
# RawGAT                      75.82/30.78               77.19/29.22
# Wave2Vec2                   50.95/48.89               61.67/40.20
# Wave2Vec2-old1  98.17/$\phantom{0}$4.82   99.98/$\phantom{0}$0.42
# WaveLM          96.43/$\phantom{0}$6.25   99.51/$\phantom{0}$1.39
# WaveLM-old1     99.94/$\phantom{0}$0.78  100.00/$\phantom{0}$0.15
# LibriSeVoc                  67.29/36.58               68.89/34.94
# AudioClip                   89.87/18.36               87.91/19.86
# Wav2Clip                    94.30/13.02               79.51/28.00
# AASIST                      77.12/29.68               74.42/31.67
# SFATNet                     92.34/15.03               86.56/20.65
# ASDG            98.84/$\phantom{0}$6.43               81.28/22.58
# Ours/ResNet     99.14/$\phantom{0}$3.95   97.10/$\phantom{0}$8.09
#
# task                                                              \
# method                                3                        5
# model
# LCNN                        74.52/31.76  99.33/$\phantom{0}$3.64
# RawNet2                     65.79/38.44              78.56/28.23
# RawGAT                      74.25/32.18              85.69/21.53
# Wave2Vec2                   58.58/43.55              64.15/38.63
# Wave2Vec2-old1              94.40/11.09  97.33/$\phantom{0}$6.24
# WaveLM                      94.80/11.04  96.28/$\phantom{0}$6.21
# WaveLM-old1     98.09/$\phantom{0}$5.76  99.68/$\phantom{0}$2.00
# LibriSeVoc                  62.76/39.82              69.64/34.79
# AudioClip                   71.09/34.16              93.81/13.89
# Wav2Clip                    84.10/24.13              75.02/31.45
# AASIST                      77.29/29.67              89.67/18.61
# SFATNet                     79.31/28.05  96.55/$\phantom{0}$9.34
# ASDG                        84.61/21.88  99.84/$\phantom{0}$1.59
# Ours/ResNet                 94.18/11.76  99.80/$\phantom{0}$1.97
#
# task
# method                              999
# model
# LCNN                        85.14/19.94
# RawNet2                     74.31/31.54
# RawGAT                      78.24/28.43
# Wave2Vec2                   58.84/42.82
# Wave2Vec2-old1  97.47/$\phantom{0}$5.64
# WaveLM          96.76/$\phantom{0}$6.22
# WaveLM-old1     99.43/$\phantom{0}$2.17
# LibriSeVoc                  67.15/36.53
# AudioClip                   85.67/21.57
# Wav2Clip                    83.23/24.15
# AASIST                      79.62/27.41
# SFATNet                     88.69/18.27
# ASDG                        91.14/13.12
# Ours/ResNet     97.55/$\phantom{0}$6.44

# %%
tasks = ["wavefake_cross_method"]

res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=True)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_method/version_0/test.csv
# Wave2Vec2 wavefake_cross_method [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# task               wavefake_cross_method                           \
# method                                 2                        3
# model
# LCNN             99.67/$\phantom{0}$2.60  99.75/$\phantom{0}$2.18
# RawNet2                      70.29/35.28              65.53/39.05
# RawGAT           96.27/$\phantom{0}$7.48              92.94/13.84
# Wave2Vec2-old1   95.58/$\phantom{0}$5.58  93.91/$\phantom{0}$9.43
# WaveLM                       61.85/38.73              61.32/39.39
# WaveLM-old1      99.99/$\phantom{0}$0.30  99.84/$\phantom{0}$1.75
# LibriSeVoc                   63.32/39.90              61.47/41.24
# AudioClip        99.87/$\phantom{0}$1.61  99.64/$\phantom{0}$2.89
# Wav2Clip         99.79/$\phantom{0}$2.02  99.88/$\phantom{0}$1.41
# AASIST           98.99/$\phantom{0}$4.86              94.30/13.04
# SFATNet                      72.21/33.60              70.61/34.88
# ASDG             99.83/$\phantom{0}$2.25  99.90/$\phantom{0}$1.11
# Ours/ResNet     100.00/$\phantom{0}$0.13  99.99/$\phantom{0}$0.29
#
# task                                                               \
# method                                4                         5
# model
# LCNN            98.88/$\phantom{0}$5.02  100.00/$\phantom{0}$0.07
# RawNet2                     63.14/40.78   99.68/$\phantom{0}$2.67
# RawGAT                      92.43/14.47   96.63/$\phantom{0}$4.42
# Wave2Vec2-old1              92.47/11.77   95.70/$\phantom{0}$4.94
# WaveLM                      61.88/39.44               61.25/39.10
# WaveLM-old1     99.12/$\phantom{0}$4.21  100.00/$\phantom{0}$0.22
# LibriSeVoc                  59.22/43.05   98.83/$\phantom{0}$5.01
# AudioClip       98.91/$\phantom{0}$5.25   99.99/$\phantom{0}$0.26
# Wav2Clip        98.96/$\phantom{0}$4.81   99.99/$\phantom{0}$0.25
# AASIST                      93.14/14.61   99.99/$\phantom{0}$0.25
# SFATNet                     70.34/35.12               71.71/33.89
# ASDG            99.71/$\phantom{0}$3.64   99.95/$\phantom{0}$0.16
# Ours/ResNet     99.88/$\phantom{0}$1.35  100.00/$\phantom{0}$0.02
#
# task                                                                \
# method                                 6                         7
# model
# LCNN             99.08/$\phantom{0}$4.51   99.99/$\phantom{0}$0.46
# RawNet2                      86.63/21.44               84.62/23.36
# RawGAT           95.88/$\phantom{0}$7.06   98.33/$\phantom{0}$5.41
# Wave2Vec2-old1   96.58/$\phantom{0}$4.76   95.95/$\phantom{0}$6.12
# WaveLM                       63.39/37.61               62.05/38.66
# WaveLM-old1      99.98/$\phantom{0}$0.51   99.89/$\phantom{0}$1.35
# LibriSeVoc                   79.14/27.61               73.84/32.11
# AudioClip        96.72/$\phantom{0}$9.67   99.86/$\phantom{0}$1.58
# Wav2Clip         99.58/$\phantom{0}$3.01   99.96/$\phantom{0}$0.76
# AASIST           99.25/$\phantom{0}$3.86   99.67/$\phantom{0}$2.25
# SFATNet                      70.85/34.61               67.16/37.29
# ASDG             99.79/$\phantom{0}$2.88   99.95/$\phantom{0}$0.18
# Ours/ResNet     100.00/$\phantom{0}$0.12  100.00/$\phantom{0}$0.01
#
# task
# method                              999
# model
# LCNN            99.56/$\phantom{0}$2.47
# RawNet2                     78.31/27.10
# RawGAT          95.41/$\phantom{0}$8.78
# Wave2Vec2-old1  95.03/$\phantom{0}$7.10
# WaveLM                      61.96/38.82
# WaveLM-old1     99.80/$\phantom{0}$1.39
# LibriSeVoc                  72.64/31.49
# AudioClip       99.16/$\phantom{0}$3.55
# Wav2Clip        99.69/$\phantom{0}$2.04
# AASIST          97.56/$\phantom{0}$6.48
# SFATNet                     70.48/34.90
# ASDG            99.86/$\phantom{0}$1.70
# Ours/ResNet     99.98/$\phantom{0}$0.32

# %%
tasks = ["LibriSeVoc_cross_method", "wavefake_cross_method"]
tasks = ["LibriSeVoc_cross_method"]

res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=False)
res.display(show_latex=0).to_csv("cross_method.csv")

# %% [markdown]
# ## Cross Dataset

# %% [markdown]
# - version 2: seed is 1
# - con_loss_feat_voc/ResNet": seed 2
# - - con_loss_feat/ResNet": seed 1

# %%
_MODELs_VERSIONS = deepcopy(MODELs_VERSIONS)
_MODELs_VERSIONS.update({
    "Ours/ResNet": [1, 5, 6, 7, 8, 13, 14, 15, 16, 20]
    
})
models = list(_MODELs_VERSIONS.keys())
versions = list(_MODELs_VERSIONS.values())

# %%
res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=["LibriSeVoc_cross_dataset"], acc=0)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/LCNN/LibriSeVoc_cross_dataset/version_0/test.csv
# LCNN LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawNet2/LibriSeVoc_cross_dataset/version_0/test.csv
# RawNet2 LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawGAT/LibriSeVoc_cross_dataset/version_0/test.csv
# RawGAT LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/WaveLM/LibriSeVoc_cross_dataset/version_0/test.csv
# WaveLM LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/AudioClip/LibriSeVoc_cross_dataset/version_0/test.csv
# AudioClip LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/AASIST/LibriSeVoc_cross_dataset/version_0/test.csv
# AASIST LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/SFATNet/LibriSeVoc_cross_dataset/version_0/test.csv
# SFATNet LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/ASDG/LibriSeVoc_cross_dataset/version_0/test.csv
# ASDG LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# task            LibriSeVoc_cross_dataset                           \
# method                                 0                        1
# model
# Wave2Vec2                    68.79/34.71              63.10/39.85
# Wave2Vec2-old1               78.83/27.84              66.28/38.50
# WaveLM-old1      95.59/$\phantom{0}$9.64              90.34/16.69
# LibriSeVoc       98.20/$\phantom{0}$6.26              71.01/34.28
# Wav2Clip         99.11/$\phantom{0}$3.36              93.41/13.52
# Ours/ResNet     100.00/$\phantom{0}$0.09  99.35/$\phantom{0}$3.86
#
# task                                                              \
# method                                2                        3
# model
# Wave2Vec2                   66.81/36.60              61.14/41.52
# Wave2Vec2-old1              80.37/26.11              63.10/41.00
# WaveLM-old1     96.95/$\phantom{0}$7.65              88.44/18.78
# LibriSeVoc                  80.10/26.49              59.98/42.66
# Wav2Clip        98.03/$\phantom{0}$6.57  96.10/$\phantom{0}$9.99
# Ours/ResNet     99.41/$\phantom{0}$3.57  99.41/$\phantom{0}$3.62
#
# task                                                              \
# method                                4                        5
# model
# Wave2Vec2                   59.74/42.68              67.96/35.34
# Wave2Vec2-old1              63.96/40.42              72.38/33.76
# WaveLM-old1                 83.92/23.34              94.03/12.00
# LibriSeVoc                  71.81/33.74              91.07/15.84
# Wav2Clip        97.02/$\phantom{0}$8.57  97.63/$\phantom{0}$6.02
# Ours/ResNet     99.35/$\phantom{0}$3.80  99.99/$\phantom{0}$0.27
#
# task                                                               \
# method                                 6                      avg
# model
# Wave2Vec2                    70.84/33.20              65.48/37.70
# Wave2Vec2-old1               79.90/26.57              72.12/33.46
# WaveLM-old1                  86.59/20.33              90.83/15.49
# LibriSeVoc       99.94/$\phantom{0}$0.97              81.73/22.89
# Wav2Clip         99.96/$\phantom{0}$0.66  97.32/$\phantom{0}$6.96
# Ours/ResNet     100.00/$\phantom{0}$0.04  99.64/$\phantom{0}$2.18
#
# task
# method                   ch                       en    inTheWild
# model
# Wave2Vec2       66.13/37.79              56.59/46.33  72.16/30.96
# Wave2Vec2-old1  81.03/26.17              68.20/37.26  96.18/10.22
# WaveLM-old1     75.47/28.74              59.58/43.89  89.91/17.19
# LibriSeVoc      62.33/40.87              45.92/53.34  83.31/24.68
# Wav2Clip        83.70/23.80              67.63/38.34  28.91/66.89
# Ours/ResNet     88.84/17.77  97.81/$\phantom{0}$6.88  48.86/51.49

# %%
res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=["LibriSeVoc_cross_dataset"], acc=0, calc_avg_on_version=False)
res.display(show_latex=0).to_csv("cross_dataset.csv")
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/LCNN/LibriSeVoc_cross_dataset/version_0/test.csv
# LCNN LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawNet2/LibriSeVoc_cross_dataset/version_0/test.csv
# RawNet2 LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/RawGAT/LibriSeVoc_cross_dataset/version_0/test.csv
# RawGAT LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/WaveLM/LibriSeVoc_cross_dataset/version_0/test.csv
# WaveLM LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/AudioClip/LibriSeVoc_cross_dataset/version_0/test.csv
# AudioClip LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/AASIST/LibriSeVoc_cross_dataset/version_0/test.csv
# AASIST LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/SFATNet/LibriSeVoc_cross_dataset/version_0/test.csv
# SFATNet LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/ASDG/LibriSeVoc_cross_dataset/version_0/test.csv
# ASDG LibriSeVoc_cross_dataset [0, 1, 2, 3, 4, 6, 7, 8, 9, 10] cannot set a frame with no defined columns

# %% [markdown]
# ## Cross Language

# %% [markdown]
# - wavefake: seed 22
# - DECRO chinese: seed 7
# - - DECRO chinese: seed 7

# %%
_MODELs_VERSIONS = deepcopy(MODELs_VERSIONS)
_MODELs_VERSIONS.update({})
models = list(MODELs_VERSIONS.keys())
versions = list(MODELs_VERSIONS.values())

# %%
tasks = ["wavefake_cross_lang", "DECRO_chinese", "DECRO_english"]

res = DisplayInnerEvaluation(
    models,
    versions=versions,
    tasks=tasks,
    acc=0,
    auc=0,
    task_classes=CROSS_LANGUAGE_TASKCLASSES,
    calc_avg_on_version=True,
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_6/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_7/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_8/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_9/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_10/test.csv
# task           wavefake_cross_lang DECRO_chinese DECRO_english    avg
# model
# LCNN                          6.74         44.14         35.68  28.85
# RawNet2                      32.93         44.97         45.17  41.02
# RawGAT                       12.86         43.66         42.53  33.02
# Wave2Vec2                    47.52         44.55         37.98  43.35
# Wave2Vec2-old1               16.90         37.10         30.49  28.16
# WaveLM                       15.17         42.37         37.46  31.67
# WaveLM-old1                  10.22         42.37         35.55  29.38
# LibriSeVoc                   36.80         35.81         41.74  38.11
# AudioClip                    46.66         49.45         45.26  47.12
# Wav2Clip                     23.17         33.74         21.66  26.19
# AASIST                       13.04         43.64         40.90  32.53
# SFATNet                      37.03         30.47         33.79  33.76
# ASDG                          7.25         43.30         36.04  28.86
# Ours/ResNet                  23.26         16.66         33.16  24.36

# %%
tasks = ["wavefake_cross_lang", "DECRO_chinese", "DECRO_english"]

res = DisplayInnerEvaluation(
    models, versions=versions, tasks=tasks, acc=0, task_classes=CROSS_LANGUAGE_TASKCLASSES, calc_avg_on_version=False
)
res.display(show_latex=0).to_csv("cross_language.csv")
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_6/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_7/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_8/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_9/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2/wavefake_cross_lang/version_10/test.csv

# %% [markdown]
# # ASVspoof

# %%
_MODELs_VERSIONS = {
    # "Wave2Vec2": range(15),
    "Wave2Vec2-new": list(range(0, 30)),
    # "WaveLM-old1": range(30)
}
_MODELs_VERSIONS.update({
    
})
models = list(_MODELs_VERSIONS.keys())
versions = list(_MODELs_VERSIONS.values())

# %%
tasks = ["ASV2021_inner"]
res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=tasks, acc=0, auc=0)
res.display(show_latex=1)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_11/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_12/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_13/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_14/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_15/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_16/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_17/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_18/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_19/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_20/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_21/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_22/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_23/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_24/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_25/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_26/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_27/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_28/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_29/test.csv
# \begin{tabular}{lrr}
# task & \multicolumn{7}{r}{ASV2021-inner} \\
# method & 0inner & 1AR & 2Non-AR & 3traditional & 4unknown & 5concat & 6whole \\
# model &  &  &  &  &  &  &  \\
# Wave2Vec2-new & 24.28 & 21.58 & 18.96 & 18.25 & 18.85 & 25.56 & 20.22 \\
# \end{tabular}
# task          ASV2021_inner                                               \
# method               0inner    1AR 2Non-AR 3traditional 4unknown 5concat
# model
# Wave2Vec2-new         24.28  21.58   18.96        18.25    18.85   25.56
#
# task
# method        6whole
# model
# Wave2Vec2-new  20.22

# %%
tasks = ["ASV2021_inner"]
res = DisplayCrossMethodEvaluation(models, versions=versions, tasks=tasks, acc=0, calc_avg_on_version=False)
res.display(show_latex=0).to_csv("ASV.csv")
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_11/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_12/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_13/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_14/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_15/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_16/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_17/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_18/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_19/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_20/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_21/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_22/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_23/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_24/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_25/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_26/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_27/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_28/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio-new/Wave2Vec2-new/ASV2021_inner/version_29/test.csv
