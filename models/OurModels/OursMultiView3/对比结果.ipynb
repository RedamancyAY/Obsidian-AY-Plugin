# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd

# %%
import importlib.util

file_path = "/home/ay/Coding2/0-Deepfake/2-Audio/0-实验结果/utils.py"
# Load the module
spec = importlib.util.spec_from_file_location("utils", file_path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
# List of function names to import
function_names = [
    "Display_ASV2021_evaluation",
    "Display_ASV2021_LA_evaluation",
    "Display_ASV2019_LA_evaluation",
    "Display_MLAAD_evaluation",
]
# Loop through the function names and add them to the global namespace
for func_name in function_names:
    if hasattr(module, func_name):
        globals()[func_name] = getattr(module, func_name)

# %%
MODELs_VERSIONS = {
    "LCNN": 0,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "MPE_LCNN": 0,
    "ABCNet": 0,
    "ASDG": 0,
    "MultiViewCombine/ablations/aasist_LCNN": 0,
    "MultiViewCombine/ablations/aasist_resnet": 0,
    "MultiViewCombine/ablations/rawnet_LCNN": 0,
    "MultiViewCombine/ablations/rawnet_resnet": 0,
    "MultiViewCombine/ablations/wavlm_resnet": 0,
    "MultiViewCombine/ablations/wavlm_LCNN": 0,
    "OursMultiView3-old": [0, 1, 2, 3, 4, 5],
    "OursMultiView3": [0, 1, 2, 3, 4, 5],
    # "OursMultiView3/ablations/loss7": range(5),
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

# %% [markdown]
# # ASV 2021

# %%
MODELs_VERSIONS.update({})

res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", calc_avg=False
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2021_inner/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2021_inner/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2021_inner/version_5/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_inner/version_3/test.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>inner</th>
#       <th>neural_vocoder_autoregressive</th>
#       <th>neural_vocoder_nonautoregressive</th>
#       <th>traditional_vocoder</th>
#       <th>unknown</th>
#       <th>waveform_concatenation</th>
#       <th>whole</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(),
    versions=MODELs_VERSIONS.values(),
    task="ASV2021_inner",
    calc_avg=False,
    auc=0,
    file_name="noise_bg_20"
)
res.display(show_latex=1)
# Out:
# LCNN 0 Length of values (7) does not match length of index (6)
# WaveLM 0 Length of values (7) does not match length of index (4)
# ABCNet 0 Length of values (7) does not match length of index (6)
# ASDG 0 Length of values (7) does not match length of index (6)
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/ASV2021_inner/version_0/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/ASV2021_inner/version_0/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_LCNN/ASV2021_inner/version_0/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_resnet/ASV2021_inner/version_0/noise_bg_20.csv
# ...

# %%
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(),
    versions=MODELs_VERSIONS.values(),
    task="ASV2021_inner",
    calc_avg=False,
    auc=0,
    file_name="noise_bg_20-filter_ASV2021"
)
res.display(show_latex=1, drop=["waveform_concatenation"])
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/ASV2021_inner/version_0/noise_bg_20-filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/ASV2021_inner/version_0/noise_bg_20-filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_LCNN/ASV2021_inner/version_0/noise_bg_20-filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_resnet/ASV2021_inner/version_0/noise_bg_20-filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/wavlm_resnet/ASV2021_inner/version_0/noise_bg_20-filter_ASV2021.csv
# ...

# %%
res = Display_ASV2021_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_LA", calc_avg=False, acc=0, auc=1
)
res.display(show_latex=0, drop=["2019LA"])
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_LCNN/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_resnet/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/wavlm_resnet/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/wavlm_LCNN/ASV2021_LA/version_0/test.csv
# ...

# %%
res = Display_ASV2021_LA_evaluation(
    models=MODELs_VERSIONS.keys(),
    versions=MODELs_VERSIONS.values(),
    task="ASV2021_LA",
    calc_avg=False,
    acc=0,
    auc=1,
    file_name="filter_ASV2021",
)
res.display(show_latex=1, drop=["2019LA", "concatenation"])
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/ASV2021_LA/version_0/filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/ASV2021_LA/version_0/filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_LCNN/ASV2021_LA/version_0/filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/rawnet_resnet/ASV2021_LA/version_0/filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/wavlm_resnet/ASV2021_LA/version_0/filter_ASV2021.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/wavlm_LCNN/ASV2021_LA/version_0/filter_ASV2021.csv
# ...

# %% [markdown]
# # ASV2019 LA

# %% [markdown]
# train on ASV2019 LA, but test on
# 1. ASV2019 LA test split
# 2. ASV2021 whole test split
# 3. ASV2021 test splits on five categorys
#     - neural_vocoder_autoregressive
#     - neural_vocoder_nonautoregressive
#     - traditional_vocoder
#     - unknown
#     - waveform_concatenation

# %%
MODELs_VERSIONS.update(
    {
        "OursPhonemeGAT": range(0, 11),
    }
)

res = Display_ASV2019_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2019_LA", calc_avg=False, acc=0, auc=0
)
res.display(show_latex=1, drop=None)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2019_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2019_LA/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3-old/ASV2019_LA/version_5/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2019_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2019_LA/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2019_LA/version_5/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ASV2019_LA/version_3/test.csv
# ...

# %% [markdown]
# # MLAAD

# %%
MODELs_VERSIONS = {
    "LCNN": 1,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "MPE_LCNN": 0,
    "ABCNet": 0,
    "ASDG": [0],
    "MultiViewCombine/ablations/aasist_LCNN": 0,
    "MultiViewCombine/ablations/aasist_resnet": 0,
    "MultiViewCombine/ablations/rawnet_LCNN": 0,
    "MultiViewCombine/ablations/rawnet_resnet": 0,
    "MultiViewCombine/ablations/wavlm_resnet": 0,
    "MultiViewCombine/ablations/wavlm_LCNN": 0,
    # "OursPhonemeGAT/ablations/no_GAT":  range(12),
    "OursMultiView3-old": [0, 1, 2, 3, 4],
    "OursMultiView3": [0, 1, 2, 3, 4],
    "OursMultiView3/ablations/loss7": range(5),
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

res = Display_MLAAD_evaluation(models, versions, task="MLAAD_cross_lang", auc=1, acc=0, calc_avg=False)
res.display(show_latex=1)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/MLAAD_cross_lang/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/MLAAD_cross_lang/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/loss7/MLAAD_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/loss7/MLAAD_cross_lang/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/loss7/MLAAD_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/loss7/MLAAD_cross_lang/version_3/test.csv
# ...

# %% [markdown]
# # Ablations

# %%
MODELs_VERSIONS = {
    "OursMultiView3": range(5),
    "OursMultiView3/ablations/no-cls_loss_1_2": range(7),
    "OursMultiView3/ablations/no-fusion": range(7),
    "OursMultiView3/ablations/no-fusion-no-CL-no-loss": range(7),
    "OursMultiView3/ablations/no-inner-CL": range(7),
    "OursMultiView3/ablations/no-inter-CL": range(7),
    "OursMultiView3/ablations/no-inner-inter-CL": range(7),
    "OursMultiView3/ablations/no-fusion-no-inner-inter-CL": range(7),
    "OursMultiView3-old": range(5),
    "OursMultiView3-old/ablations/no-cls_loss_1_2": range(7),
    "OursMultiView3-old/ablations/no-fusion": range(7),
    "OursMultiView3-old/ablations/no-fusion-no-CL-no-loss": range(7),
    "OursMultiView3-old/ablations/no-inner-CL": range(7),
    "OursMultiView3-old/ablations/no-inter-CL": range(7),
    "OursMultiView3-old/ablations/no-inner-inter-CL": range(7),
    "OursMultiView3-old/ablations/no-fusion-no-inner-inter-CL": range(7),
    # "OursMultiView3/ablations/loss1": range(5),
    # "OursMultiView3/ablations/loss2": range(5),
    # "OursMultiView3/ablations/loss3": range(5),
    # "OursMultiView3/ablations/loss4": range(5),
    # "OursMultiView3/ablations/loss5": range(5),
    # "OursMultiView3/ablations/loss6": range(5),
    # "OursMultiView3/ablations/loss7": range(5),
    # "OursMultiView3/ablations/loss8": range(5),
    # "OursMultiView3/ablations/loss9": range(5),
    # "OursMultiView3/ablations/loss10": range(5),
}


models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

res = Display_MLAAD_evaluation(models, versions, task="MLAAD_cross_lang", auc=0, acc=1, calc_avg=False)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/MLAAD_cross_lang/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/MLAAD_cross_lang/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/MLAAD_cross_lang/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/MLAAD_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/MLAAD_cross_lang/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/MLAAD_cross_lang/version_4/test.csv
# ...

# %%
res = Display_ASV2019_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2019_LA", calc_avg=False, acc=0, auc=0
)
res.display(show_latex=0, drop=None)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2019_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2019_LA/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2019_LA/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2019_LA/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2019_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2019_LA/version_4/test.csv
# ...

# %%
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", calc_avg=False
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_inner/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_inner/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_inner/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_inner/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_inner/version_4/test.csv
# ...

# %%
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(),
    versions=MODELs_VERSIONS.values(),
    task="ASV2021_inner",
    calc_avg=False,
    file_name="noise_bg_20",
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_inner/version_3/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_inner/version_4/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_inner/version_1/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_inner/version_2/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_inner/version_3/noise_bg_20.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_inner/version_4/noise_bg_20.csv
# ...

# %%
res = Display_ASV2021_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_LA", calc_avg=False, acc=0, auc=1
)
res.display(show_latex=0, drop=["2019LA"])
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ASV2021_LA/version_4/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-cls_loss_1_2/ASV2021_LA/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_LA/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_LA/version_3/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView3/ablations/no-fusion-no-CL-no-loss/ASV2021_LA/version_4/test.csv
# ...
