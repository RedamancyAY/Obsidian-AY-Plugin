# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from utils import (
    # display_ASV2019LA_evaluation,
    # display_ASV2021_evaluation,
    # display_ASV2021_evaluation_versions,
    # display_ASV2021LA_evaluation,
    display_cross_dataset_evaluation,
    display_cross_language_evaluation,
    display_cross_method_evaluation,
    display_inner_evaluation,
)

# %%
MODELs_VERSIONS = {
    "LCNN": 0,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "MPE_LCNN":0,
    "ABCNet":0,
    "MultiViewCombine/ablations/aasist_LCNN":0,
    "MultiViewCombine/ablations/aasist_resnet":0,
    "MultiViewCombine/ablations/rawnet_LCNN":0,
    "MultiViewCombine/ablations/rawnet_resnet":0,
    "OursMultiView2": 0,
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

# %% [markdown]
# # Inner evaluation

# %%
V = 0
MODELs_VERSIONS.update(
    {
        # "OursMultiView2": 1,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()


data = display_inner_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    tasks=["LibriSeVoc_inner", "wavefake_inner", "ASV2021_inner", "ASV2021_LA", "ASV2019_LA"],
    avg_res=False,
)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_LCNN/ASV2021_LA/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/MultiViewCombine/ablations/aasist_resnet/ASV2021_LA/version_0/test.csv
# ...

# %% [markdown]
# # ASV 2021

# %%
from utils import Display_ASV2021_evaluation, Display_ASV2021_LA_evaluation, Display_ASV2019_LA_evaluation

# %%
MODELs_VERSIONS.update(
    {
    }
)

res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", calc_avg=False
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/AASIST/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursMultiView2/ASV2021_inner/version_3/test.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>inner</th>
#       <th>neural_vocoder_autoregressive</th>
#       <th>neural_vocoder_nonautoregressive</th>
#       <th>traditional_vocoder</th>
#       <th>unknown</th>
#       <th>waveform_concatenation</th>
#       <th>whole</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$91.65$ / $16.70$</td>
#       <td>$85.24$ / $24.28$</td>
#       <td>$83.96$ / $25.51$</td>
#       <td>$92.16$ / $16.77$</td>
# ...

# %%
MODELs_VERSIONS.update({"OursMultiView2": 5, "RawGAT": 1})

data = display_ASV2021_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>inner</th>
#       <th>neural_vocoder_autoregressive</th>
#       <th>neural_vocoder_nonautoregressive</th>
#       <th>traditional_vocoder</th>
#       <th>unknown</th>
#       <th>waveform_concatenation</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$91.65$ / $16.70$</td>
#       <td>$85.24$ / $24.28$</td>
#       <td>$83.96$ / $25.51$</td>
#       <td>$92.16$ / $16.77$</td>
#       <td>$89.87$ / $19.68$</td>
#       <td>$90.02$ / $18.42$</td>
#       <td>$88.82$ / $20.23$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$87.32$ / $21.09$</td>
#       <td>$81.12$ / $27.36$</td>
#       <td>$82.62$ / $26.02$</td>
# ...

# %%
display_ASV2021_evaluation_versions("OursMultiView2/ablations/ab", versions=list(range(50)))

# %% [markdown]
# # ASV2019 LA

# %% [markdown]
# train on ASV2019 LA, but test on
# 1. ASV2019 LA test split
# 2. ASV2021 whole test split
# 3. ASV2021 test splits on five categorys
#     - neural_vocoder_autoregressive
#     - neural_vocoder_nonautoregressive
#     - traditional_vocoder
#     - unknown
#     - waveform_concatenation

# %%
MODELs_VERSIONS.update({"OursMultiView2": 3, "AASIST": 1,})


display_ASV2019LA_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>inner</th>
#       <th>2021test</th>
#       <th>autoregressive</th>
#       <th>nonautoregressive</th>
#       <th>traditional</th>
#       <th>unknown</th>
#       <th>concatenation</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$95.69$ / $11.37$</td>
#       <td>$84.43$ / $23.90$</td>
#       <td>$77.71$ / $29.56$</td>
#       <td>$77.39$ / $29.67$</td>
#       <td>$84.57$ / $23.25$</td>
#       <td>$93.94$ / $13.30$</td>
#       <td>$94.89$ / $12.56$</td>
#       <td>$86.95$ / $20.52$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$94.94$ / $11.38$</td>
#       <td>$84.51$ / $25.31$</td>
# ...

# %%
MODELs_VERSIONS.update(
    {
        "OursMultiView2": 22,
        "AASIST": 1,
    }
)
datas = []
for x in ["noise_bg_20", "noise_bg_30", "noise_gaussian_20", "noise_gaussian_30"]:
    _data = display_inner_evaluation(
        models=models,
        versions=versions,
        show_latex=0,
        show_html=0,
        tasks=["ASV2019_LA"],
        avg_res=False,
        file_name=x,
    )
    _data.columns = [x]
    datas.append(_data)
pd.concat(datas, axis=1)
# Out:
#                       noise_bg_20        noise_bg_30  noise_gaussian_20  \
# model
# LCNN            $74.22$ / $32.31$  $79.72$ / $28.15$  $83.60$ / $24.47$
# RawNet2         $83.23$ / $26.38$  $84.37$ / $25.48$  $84.72$ / $25.09$
# RawGAT          $86.93$ / $22.00$  $88.40$ / $20.68$  $88.25$ / $21.33$
# Wave2Vec2       $80.12$ / $28.54$  $82.58$ / $26.34$  $81.17$ / $28.47$
# WaveLM          $77.28$ / $31.00$  $79.24$ / $29.77$  $77.65$ / $31.36$
# LibriSeVoc      $84.25$ / $25.81$  $85.69$ / $24.67$  $85.80$ / $24.63$
# AudioClip       $82.46$ / $26.03$  $84.20$ / $24.60$  $82.99$ / $25.68$
# Wav2Clip        $78.33$ / $28.91$  $82.71$ / $25.47$  $54.44$ / $47.03$
# AASIST          $86.75$ / $22.63$  $88.90$ / $20.44$  $88.96$ / $20.37$
# OursMultiView2  $78.11$ / $29.59$  $83.07$ / $25.32$  $85.63$ / $23.46$
#
#                 noise_gaussian_30
# model
# LCNN            $84.76$ / $23.48$
# RawNet2         $84.57$ / $25.27$
# RawGAT          $88.57$ / $20.63$
# ...

# %% [markdown]
# # ASV2021 LA

# %% [markdown]
# train on ASV2021 LA, but test on
# 1. ASV2021 LA test split
# 2. ASV2019 LA test split
# 3. ASV2021 whole test split
# 4. ASV2021 test splits on five categorys
#     - neural_vocoder_autoregressive
#     - neural_vocoder_nonautoregressive
#     - traditional_vocoder
#     - unknown
#     - waveform_concatenation

# %%
MODELs_VERSIONS.update({"OursMultiView2": 7})

display_ASV2021LA_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>inner</th>
#       <th>2019LA</th>
#       <th>2021test</th>
#       <th>autoregressive</th>
#       <th>nonautoregressive</th>
#       <th>traditional</th>
#       <th>unknown</th>
#       <th>concatenation</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$98.16$ / $\phantom{0}6.53$</td>
#       <td>$98.30$ / $\phantom{0}6.20$</td>
#       <td>$84.21$ / $25.02$</td>
#       <td>$82.69$ / $26.45$</td>
#       <td>$83.15$ / $25.87$</td>
#       <td>$85.10$ / $24.53$</td>
#       <td>$84.75$ / $24.51$</td>
#       <td>$87.17$ / $21.37$</td>
#       <td>$87.94$ / $20.06$</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Cross method

# %%
# V = 0
MODELs_VERSIONS.update(
    {
        "OursMultiView2": 0,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_method_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    # tasks=["LibriSeVoc_cross_method", "wavefake_cross_method"],
    tasks=["LibriSeVoc_cross_method", "ASV2021_inner"],
    auc=0,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>dataset</th>
#       <th colspan="5" halign="left">LibriSeVoc</th>
#       <th colspan="6" halign="left">ASV2021</th>
#     </tr>
#     <tr>
#       <th>method</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>5</th>
#       <th>999</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>999</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$\phantom{0}3.81$</td>
#       <td>$21.92$</td>
#       <td>$14.54$</td>
#       <td>$\phantom{0}0.53$</td>
#       <td>$10.20$</td>
#       <td>$24.28$</td>
#       <td>$25.51$</td>
#       <td>$16.77$</td>
# ...

# %%
# V = 0
MODELs_VERSIONS.update(
    {
        "OursMultiView2": 0,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_method_evaluation(
    models=models, versions=versions, show_latex=1, tasks=["wavefake_cross_method"], auc=1
)

# %% [markdown]
# ## Cross Dataset

# %%
V = 1
MODELs_VERSIONS.update(
    {
        "OursMultiView2": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_dataset_evaluation(
    models=models,
    versions=versions,
    show_latex=1,
    tasks=[
        "LibriSeVoc_cross_dataset",
        # "DECRO_chinese",
        # "DECRO_english",
    ],
    only_LibriSeVoc=False,
)

# %% [markdown]
# ## Cross Language

# %%
V = 1
MODELs_VERSIONS.update(
    {
        "OursMultiView": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()
data = display_cross_language_evaluation(models=models, versions=versions, show_latex=0, auc=1)

# %% [markdown]
# # Ablations

# %%
_MODELs_VERSIONS = {
    "OursMultiView2": 0,
    "OursMultiView2/ablations/no-cls_loss_1_2": 0,
    "OursMultiView2/ablations/no-fusion": 0,
    "OursMultiView2/ablations/no-inner-CL": 0,
    "OursMultiView2/ablations/no-inner-inter-CL": 0,
    "OursMultiView2/ablations/no-inter-CL": 0,
}

_models = _MODELs_VERSIONS.keys()
_versions = _MODELs_VERSIONS.values()


data = display_cross_method_evaluation(models=_models, versions=_versions, show_latex=0, tasks=["ASV2021_inner"], auc=0)
