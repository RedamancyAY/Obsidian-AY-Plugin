# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import (
    display_cross_dataset_evaluation,
    display_cross_language_evaluation,
    display_cross_method_evaluation,
    display_inner_evaluation,
)

# %%
MODELs_VERSIONS = {
    "Ours/ResNet": 0,
    "Ours/ablations/con_loss_feat/ResNet": 0,
    "Ours/ablations/con_loss_voc/ResNet": 0,
    "Ours/ablations/con_loss_feat_voc/ResNet": 0,
    "Ours/ablations/shuffle_feat/ResNet": 0,
    "Ours/ablations/shuffle_style/ResNet": 0,
    "Ours/ablations/shuffle_style_feat/ResNet": 0,
    "Ours/ablations/one_stem/ResNet": 0,
    "Ours/ablations/no_speed_compression_loss/ResNet": 0,
    "Ours/ablations/one_stem_content/ResNet": 1,
    "Ours/ablations/one_stem_vocoder/ResNet": 0,
    "Ours/ablations/use_adversarial_loss/ResNet": 0,
    "Ours/ablations/f0_loss/ResNet": 0,
    'Ours/ablations/para1/ResNet' : 1,
    'Ours/ablations/para2/ResNet' : 0,
    'Ours/ablations/para3/ResNet' : 0,
    'Ours/ablations/para4/ResNet' : 0,
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

# %% [markdown]
# ## Cross method

# %% [markdown]
# - "Ours/ablations/con_loss_voc/ResNet": seed 0
# - "Ours/ablations/con_loss_feat_voc/ResNet": seed 0
# - para1 : seed 0

# %%
# V = 0
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/para1/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_method_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    tasks=["LibriSeVoc_cross_method"],
)
# data = display_cross_method_evaluation(
#     models=models,
#     versions=versions,
#     show_latex=0,
#     tasks=["wavefake_cross_method"],
# )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>dataset</th>
#       <th colspan="5" halign="left">LibriSeVoc</th>
#     </tr>
#     <tr>
#       <th>method</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>5</th>
#       <th>999</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.11$ / $\phantom{0}3.86$</td>
#       <td>$97.28$ / $\phantom{0}7.46$</td>
#       <td>$96.48$ / $\phantom{0}8.33$</td>
#       <td>$99.87$ / $\phantom{0}1.63$</td>
#       <td>$98.19$ / $\phantom{0}5.32$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$99.07$ / $\phantom{0}4.05$</td>
#       <td>$96.98$ / $\phantom{0}8.09$</td>
#       <td>$95.13$ / $10.90$</td>
#       <td>$99.86$ / $\phantom{0}1.67$</td>
#       <td>$97.76$ / $\phantom{0}6.18$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$99.05$ / $\phantom{0}3.80$</td>
#       <td>$95.83$ / $10.43$</td>
#       <td>$96.49$ / $\phantom{0}8.24$</td>
#       <td>$99.75$ / $\phantom{0}1.89$</td>
#       <td>$97.78$ / $\phantom{0}6.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$99.02$ / $\phantom{0}4.24$</td>
#       <td>$94.74$ / $11.98$</td>
#       <td>$96.55$ / $\phantom{0}8.25$</td>
#       <td>$99.80$ / $\phantom{0}1.82$</td>
#       <td>$97.53$ / $\phantom{0}6.57$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$98.82$ / $\phantom{0}5.11$</td>
#       <td>$97.50$ / $\phantom{0}6.55$</td>
#       <td>$95.57$ / $10.11$</td>
#       <td>$99.81$ / $\phantom{0}2.16$</td>
#       <td>$97.92$ / $\phantom{0}5.98$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$98.92$ / $\phantom{0}4.77$</td>
#       <td>$97.26$ / $\phantom{0}7.56$</td>
#       <td>$94.76$ / $11.06$</td>
#       <td>$99.84$ / $\phantom{0}1.82$</td>
#       <td>$97.69$ / $\phantom{0}6.30$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$99.12$ / $\phantom{0}4.35$</td>
#       <td>$97.12$ / $\phantom{0}7.61$</td>
#       <td>$95.74$ / $\phantom{0}9.67$</td>
#       <td>$99.88$ / $\phantom{0}1.40$</td>
#       <td>$97.96$ / $\phantom{0}5.76$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem/ResNet</th>
#       <td>$97.72$ / $\phantom{0}8.25$</td>
#       <td>$93.02$ / $13.10$</td>
#       <td>$86.28$ / $21.32$</td>
#       <td>$99.16$ / $\phantom{0}5.03$</td>
#       <td>$94.04$ / $11.93$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/no_speed_compression_loss/ResNet</th>
#       <td>$97.87$ / $\phantom{0}7.31$</td>
#       <td>$89.46$ / $18.14$</td>
#       <td>$82.05$ / $25.29$</td>
#       <td>$99.26$ / $\phantom{0}4.32$</td>
#       <td>$92.16$ / $13.76$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem_content/ResNet</th>
#       <td>$98.58$ / $\phantom{0}5.05$</td>
#       <td>$94.61$ / $11.81$</td>
#       <td>$93.99$ / $12.68$</td>
#       <td>$99.66$ / $\phantom{0}2.65$</td>
#       <td>$96.71$ / $\phantom{0}8.05$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem_vocoder/ResNet</th>
#       <td>$96.79$ / $\phantom{0}9.64$</td>
#       <td>$96.04$ / $10.00$</td>
#       <td>$92.15$ / $15.68$</td>
#       <td>$99.14$ / $\phantom{0}4.85$</td>
#       <td>$96.03$ / $10.04$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/use_adversarial_loss/ResNet</th>
#       <td>$99.02$ / $\phantom{0}4.22$</td>
#       <td>$95.58$ / $10.37$</td>
#       <td>$95.80$ / $\phantom{0}9.47$</td>
#       <td>$99.82$ / $\phantom{0}1.90$</td>
#       <td>$97.56$ / $\phantom{0}6.49$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/f0_loss/ResNet</th>
#       <td>$97.54$ / $\phantom{0}7.35$</td>
#       <td>$92.70$ / $13.90$</td>
#       <td>$84.11$ / $23.33$</td>
#       <td>$99.42$ / $\phantom{0}3.82$</td>
#       <td>$93.44$ / $12.10$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para1/ResNet</th>
#       <td>$99.16$ / $\phantom{0}3.79$</td>
#       <td>$97.40$ / $\phantom{0}7.30$</td>
#       <td>$96.56$ / $\phantom{0}8.07$</td>
#       <td>$99.88$ / $\phantom{0}1.51$</td>
#       <td>$98.25$ / $\phantom{0}5.17$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para2/ResNet</th>
#       <td>$98.94$ / $\phantom{0}4.23$</td>
#       <td>$96.34$ / $\phantom{0}9.09$</td>
#       <td>$96.34$ / $\phantom{0}8.73$</td>
#       <td>$99.83$ / $\phantom{0}1.74$</td>
#       <td>$97.86$ / $\phantom{0}5.95$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para3/ResNet</th>
#       <td>$99.22$ / $\phantom{0}3.75$</td>
#       <td>$96.81$ / $\phantom{0}8.63$</td>
#       <td>$95.22$ / $10.62$</td>
#       <td>$99.88$ / $\phantom{0}1.63$</td>
#       <td>$97.78$ / $\phantom{0}6.16$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para4/ResNet</th>
#       <td>$99.01$ / $\phantom{0}3.85$</td>
#       <td>$96.65$ / $\phantom{0}8.73$</td>
#       <td>$97.01$ / $\phantom{0}7.23$</td>
#       <td>$99.85$ / $\phantom{0}1.70$</td>
#       <td>$98.13$ / $\phantom{0}5.38$</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Cross Dataset

# %% [markdown]
# - version 2: seed is 1
# - con_loss_feat_voc/ResNet": seed 2
# - - con_loss_feat/ResNet": seed 1

# %%
V = 1
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_feat/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_dataset_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    tasks=[
        "LibriSeVoc_cross_dataset",
        # "DECRO_chinese",
        # "DECRO_english",
    ],
    only_LibriSeVoc=False,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>avg</th>
#       <th>ch</th>
#       <th>en</th>
#       <th>inTheWild</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.22$</td>
#       <td>$99.65$ / $\phantom{0}2.73$</td>
#       <td>$98.82$ / $\phantom{0}5.33$</td>
#       <td>$99.57$ / $\phantom{0}3.07$</td>
#       <td>$99.32$ / $\phantom{0}3.90$</td>
#       <td>$99.92$ / $\phantom{0}0.97$</td>
#       <td>$100.00$ / $\phantom{0}0.07$</td>
#       <td>$99.61$ / $\phantom{0}2.33$</td>
#       <td>$89.06$ / $16.93$</td>
#       <td>$99.24$ / $\phantom{0}3.93$</td>
#       <td>$34.13$ / $63.53$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$99.48$ / $\phantom{0}3.44$</td>
#       <td>$96.60$ / $\phantom{0}9.62$</td>
#       <td>$99.35$ / $\phantom{0}3.89$</td>
#       <td>$98.92$ / $\phantom{0}5.11$</td>
#       <td>$99.95$ / $\phantom{0}0.79$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.19$ / $\phantom{0}3.31$</td>
#       <td>$88.05$ / $17.56$</td>
#       <td>$99.07$ / $\phantom{0}4.50$</td>
#       <td>$29.66$ / $66.92$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.37$</td>
#       <td>$99.37$ / $\phantom{0}3.70$</td>
#       <td>$99.10$ / $\phantom{0}4.47$</td>
#       <td>$99.33$ / $\phantom{0}3.95$</td>
#       <td>$99.22$ / $\phantom{0}4.32$</td>
#       <td>$99.90$ / $\phantom{0}1.20$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.56$ / $\phantom{0}2.58$</td>
#       <td>$90.94$ / $15.86$</td>
#       <td>$98.15$ / $\phantom{0}6.52$</td>
#       <td>$47.07$ / $52.72$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.33$</td>
#       <td>$97.69$ / $\phantom{0}7.57$</td>
#       <td>$98.30$ / $\phantom{0}6.28$</td>
#       <td>$98.37$ / $\phantom{0}6.19$</td>
#       <td>$98.28$ / $\phantom{0}6.29$</td>
#       <td>$99.91$ / $\phantom{0}1.24$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$98.93$ / $\phantom{0}4.00$</td>
#       <td>$85.14$ / $21.79$</td>
#       <td>$95.50$ / $10.41$</td>
#       <td>$36.22$ / $61.27$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.25$</td>
#       <td>$98.06$ / $\phantom{0}6.92$</td>
#       <td>$98.45$ / $\phantom{0}5.86$</td>
#       <td>$98.32$ / $\phantom{0}6.23$</td>
#       <td>$98.00$ / $\phantom{0}6.79$</td>
#       <td>$99.97$ / $\phantom{0}0.71$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$98.97$ / $\phantom{0}3.83$</td>
#       <td>$82.11$ / $24.00$</td>
#       <td>$94.49$ / $12.44$</td>
#       <td>$62.83$ / $41.10$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$99.97$ / $\phantom{0}0.45$</td>
#       <td>$99.41$ / $\phantom{0}3.87$</td>
#       <td>$97.69$ / $\phantom{0}7.73$</td>
#       <td>$98.78$ / $\phantom{0}5.47$</td>
#       <td>$98.56$ / $\phantom{0}5.95$</td>
#       <td>$99.85$ / $\phantom{0}1.34$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.18$ / $\phantom{0}3.56$</td>
#       <td>$89.17$ / $16.84$</td>
#       <td>$98.23$ / $\phantom{0}6.32$</td>
#       <td>$32.42$ / $63.88$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.32$</td>
#       <td>$97.56$ / $\phantom{0}7.85$</td>
#       <td>$98.04$ / $\phantom{0}6.74$</td>
#       <td>$98.21$ / $\phantom{0}6.48$</td>
#       <td>$97.76$ / $\phantom{0}7.15$</td>
#       <td>$99.97$ / $\phantom{0}0.72$</td>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$98.79$ / $\phantom{0}4.19$</td>
#       <td>$84.22$ / $22.25$</td>
#       <td>$95.11$ / $11.75$</td>
#       <td>$63.07$ / $40.57$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.20$</td>
#       <td>$92.56$ / $14.85$</td>
#       <td>$92.74$ / $14.09$</td>
#       <td>$90.10$ / $17.75$</td>
#       <td>$89.48$ / $17.82$</td>
#       <td>$99.94$ / $\phantom{0}0.67$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#       <td>$94.97$ / $\phantom{0}9.35$</td>
#       <td>$84.98$ / $22.41$</td>
#       <td>$85.29$ / $21.76$</td>
#       <td>$77.46$ / $28.99$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/no_speed_compression_loss/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$97.31$ / $\phantom{0}8.44$</td>
#       <td>$96.15$ / $\phantom{0}9.63$</td>
#       <td>$95.75$ / $10.49$</td>
#       <td>$95.82$ / $10.37$</td>
#       <td>$99.99$ / $\phantom{0}0.23$</td>
#       <td>$100.00$ / $\phantom{0}0.02$</td>
#       <td>$97.86$ / $\phantom{0}5.61$</td>
#       <td>$81.94$ / $24.37$</td>
#       <td>$92.41$ / $14.91$</td>
#       <td>$66.37$ / $39.18$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem_content/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.19$</td>
#       <td>$97.40$ / $\phantom{0}8.30$</td>
#       <td>$96.27$ / $10.11$</td>
#       <td>$97.58$ / $\phantom{0}8.10$</td>
#       <td>$98.32$ / $\phantom{0}6.46$</td>
#       <td>$99.98$ / $\phantom{0}0.54$</td>
#       <td>$100.00$ / $\phantom{0}0.02$</td>
#       <td>$98.51$ / $\phantom{0}4.82$</td>
#       <td>$88.26$ / $18.43$</td>
#       <td>$85.51$ / $22.78$</td>
#       <td>$58.35$ / $44.02$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem_vocoder/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$97.39$ / $\phantom{0}8.37$</td>
#       <td>$99.08$ / $\phantom{0}4.30$</td>
#       <td>$96.48$ / $\phantom{0}9.80$</td>
#       <td>$96.20$ / $10.13$</td>
#       <td>$100.00$ / $\phantom{0}0.20$</td>
#       <td>$100.00$ / $\phantom{0}0.07$</td>
#       <td>$98.45$ / $\phantom{0}4.70$</td>
#       <td>$78.14$ / $29.29$</td>
#       <td>$77.18$ / $30.99$</td>
#       <td>$59.66$ / $44.15$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/use_adversarial_loss/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.31$</td>
#       <td>$99.13$ / $\phantom{0}4.51$</td>
#       <td>$98.65$ / $\phantom{0}5.82$</td>
#       <td>$99.20$ / $\phantom{0}4.40$</td>
#       <td>$99.04$ / $\phantom{0}4.89$</td>
#       <td>$99.93$ / $\phantom{0}1.03$</td>
#       <td>$100.00$ / $\phantom{0}0.13$</td>
#       <td>$99.42$ / $\phantom{0}3.01$</td>
#       <td>$89.68$ / $16.91$</td>
#       <td>$98.12$ / $\phantom{0}6.91$</td>
#       <td>$47.80$ / $52.29$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/f0_loss/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.38$</td>
#       <td>$98.32$ / $\phantom{0}6.43$</td>
#       <td>$98.76$ / $\phantom{0}5.24$</td>
#       <td>$96.81$ / $\phantom{0}8.95$</td>
#       <td>$97.52$ / $\phantom{0}7.87$</td>
#       <td>$99.84$ / $\phantom{0}1.66$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$98.75$ / $\phantom{0}4.37$</td>
#       <td>$80.88$ / $27.05$</td>
#       <td>$87.10$ / $19.85$</td>
#       <td>$64.35$ / $41.13$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para1/ResNet</th>
#       <td>$99.98$ / $\phantom{0}0.41$</td>
#       <td>$99.32$ / $\phantom{0}3.98$</td>
#       <td>$98.94$ / $\phantom{0}4.97$</td>
#       <td>$99.31$ / $\phantom{0}4.05$</td>
#       <td>$99.22$ / $\phantom{0}4.26$</td>
#       <td>$99.83$ / $\phantom{0}1.59$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.51$ / $\phantom{0}2.76$</td>
#       <td>$90.13$ / $16.73$</td>
#       <td>$98.16$ / $\phantom{0}6.79$</td>
#       <td>$44.09$ / $54.87$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/para2/ResNet</th>
#       <td>$99.96$ / $\phantom{0}0.68$</td>
#       <td>$99.18$ / $\phantom{0}4.37$</td>
#       <td>$98.31$ / $\phantom{0}6.35$</td>
#       <td>$99.00$ / $\phantom{0}4.79$</td>
#       <td>$98.95$ / $\phantom{0}5.03$</td>
#       <td>$
