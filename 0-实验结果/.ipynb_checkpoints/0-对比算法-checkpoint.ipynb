# %%
# %load_ext autoreload
# %autoreload 2

# %%
from copy import deepcopy

from utils import (
    display_cross_dataset_evaluation,
    display_cross_language_evaluation,
    display_cross_method_evaluation,
    display_inner_evaluation,
)

# %%
MODELs_VERSIONS = {
    "LCNN": 0,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "SFATNet": 0,
    "ASDG": 0,
    "Ours/ResNet": 0,
    "Ours/ablations/con_loss_feat/ResNet": 0,
    "Ours/ablations/con_loss_voc/ResNet": 0,
    "Ours/ablations/con_loss_feat_voc/ResNet": 0,
    "Ours/ablations/shuffle_feat/ResNet": 0,
    "Ours/ablations/shuffle_style/ResNet": 0,
    "Ours/ablations/shuffle_style_feat/ResNet": 0,
    "Ours/ablations/one_stem/ResNet": 0,
    "Ours/ablations/use_adversarial_loss/ResNet": 0,
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

# %% [markdown]
# # Inner evaluation

# %%
V = 0
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()


data = display_inner_evaluation(
    models=models,
    versions=versions,
    show_latex=1,
)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/LibriSeVoc_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/wavefake_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/DECRO_english/version_0/test.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LibriSeVoc_inner</th>
#       <th>wavefake_inner</th>
#       <th>DECRO_english</th>
#       <th>DECRO_chinese</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.99$ / $\phantom{0}0.49$</td>
#       <td>$99.99$ / $\phantom{0}0.38$</td>
#       <td>$99.96$ / $\phantom{0}0.90$</td>
#       <td>$99.91$ / $\phantom{0}1.41$</td>
#       <td>$99.96$ / $\phantom{0}0.80$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$99.80$ / $\phantom{0}2.12$</td>
#       <td>$97.56$ / $\phantom{0}8.32$</td>
#       <td>$99.31$ / $\phantom{0}3.73$</td>
#       <td>$98.85$ / $\phantom{0}5.54$</td>
#       <td>$98.88$ / $\phantom{0}4.93$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$99.98$ / $\phantom{0}0.64$</td>
#       <td>$99.98$ / $\phantom{0}0.61$</td>
#       <td>$99.94$ / $\phantom{0}1.29$</td>
#       <td>$99.88$ / $\phantom{0}1.60$</td>
#       <td>$99.95$ / $\phantom{0}1.04$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$99.79$ / $\phantom{0}2.04$</td>
#       <td>$99.96$ / $\phantom{0}0.90$</td>
#       <td>$99.98$ / $\phantom{0}0.47$</td>
#       <td>$99.98$ / $\phantom{0}0.20$</td>
#       <td>$99.93$ / $\phantom{0}0.90$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.39$</td>
#       <td>$99.99$ / $\phantom{0}0.33$</td>
#       <td>$99.99$ / $\phantom{0}0.29$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$99.84$ / $\phantom{0}1.78$</td>
#       <td>$99.47$ / $\phantom{0}3.61$</td>
#       <td>$99.49$ / $\phantom{0}3.31$</td>
#       <td>$99.69$ / $\phantom{0}2.72$</td>
#       <td>$99.62$ / $\phantom{0}2.85$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$99.05$ / $\phantom{0}4.88$</td>
#       <td>$99.94$ / $\phantom{0}1.12$</td>
#       <td>$99.80$ / $\phantom{0}2.07$</td>
#       <td>$99.64$ / $\phantom{0}3.05$</td>
#       <td>$99.61$ / $\phantom{0}2.78$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$99.73$ / $\phantom{0}2.23$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.26$</td>
#       <td>$98.95$ / $\phantom{0}5.04$</td>
#       <td>$99.67$ / $\phantom{0}1.89$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$99.97$ / $\phantom{0}0.68$</td>
#       <td>$99.97$ / $\phantom{0}0.65$</td>
#       <td>$99.95$ / $\phantom{0}0.98$</td>
#       <td>$99.86$ / $\phantom{0}1.72$</td>
#       <td>$99.94$ / $\phantom{0}1.01$</td>
#     </tr>
#     <tr>
#       <th>SFATNet</th>
#       <td>$98.02$ / $\phantom{0}6.71$</td>
#       <td>$99.87$ / $\phantom{0}1.53$</td>
#       <td>$99.88$ / $\phantom{0}1.73$</td>
#       <td>$98.10$ / $\phantom{0}6.92$</td>
#       <td>$98.97$ / $\phantom{0}4.22$</td>
#     </tr>
#     <tr>
#       <th>ASDG</th>
#       <td>$99.93$ / $\phantom{0}0.94$</td>
#       <td>$99.93$ / $\phantom{0}0.27$</td>
#       <td>$99.91$ / $\phantom{0}1.07$</td>
#       <td>$99.68$ / $\phantom{0}1.72$</td>
#       <td>$99.86$ / $\phantom{0}1.00$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.94$ / $\phantom{0}0.57$</td>
#       <td>$100.00$ / $\phantom{0}0.10$</td>
#       <td>$99.99$ / $\phantom{0}0.55$</td>
#       <td>$99.98$ / $\phantom{0}0.47$</td>
#       <td>$99.98$ / $\phantom{0}0.42$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.99$ / $\phantom{0}0.44$</td>
#       <td>$99.99$ / $\phantom{0}0.44$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.98$ / $\phantom{0}0.44$</td>
#       <td>$99.98$ / $\phantom{0}0.44$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.99$ / $\phantom{0}0.41$</td>
#       <td>$99.99$ / $\phantom{0}0.41$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.98$ / $\phantom{0}0.44$</td>
#       <td>$99.98$ / $\phantom{0}0.44$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.97$ / $\phantom{0}0.62$</td>
#       <td>$99.97$ / $\phantom{0}0.62$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.97$ / $\phantom{0}0.72$</td>
#       <td>$99.97$ / $\phantom{0}0.72$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.97$ / $\phantom{0}0.74$</td>
#       <td>$99.97$ / $\phantom{0}0.74$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/use_adversarial_loss/ResNet</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>$99.99$ / $\phantom{0}0.41$</td>
#       <td>$99.99$ / $\phantom{0}0.41$</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrr}
#  & LibriSeVoc_inner & wavefake_inner & DECRO_english & DECRO_chinese & mean \\
# model &  &  &  &  &  \\
# LCNN & $99.99$ / $\phantom{0}0.49$ & $99.99$ / $\phantom{0}0.38$ & $99.96$ / $\phantom{0}0.90$ & $99.91$ / $\phantom{0}1.41$ & $99.96$ / $\phantom{0}0.80$ \\
# RawNet2 & $99.80$ / $\phantom{0}2.12$ & $97.56$ / $\phantom{0}8.32$ & $99.31$ / $\phantom{0}3.73$ & $98.85$ / $\phantom{0}5.54$ & $98.88$ / $\phantom{0}4.93$ \\
# RawGAT & $99.98$ / $\phantom{0}0.64$ & $99.98$ / $\phantom{0}0.61$ & $99.94$ / $\phantom{0}1.29$ & $99.88$ / $\phantom{0}1.60$ & $99.95$ / $\phantom{0}1.04$ \\
# Wave2Vec2 & $99.79$ / $\phantom{0}2.04$ & $99.96$ / $\phantom{0}0.90$ & $99.98$ / $\phantom{0}0.47$ & $99.98$ / $\phantom{0}0.20$ & $99.93$ / $\phantom{0}0.90$ \\
# WaveLM & $100.00$ / $\phantom{0}0.08$ & $99.99$ / $\phantom{0}0.39$ & $99.99$ / $\phantom{0}0.33$ & $99.99$ / $\phantom{0}0.29$ & $99.99$ / $\phantom{0}0.27$ \\
# LibriSeVoc & $99.84$ / $\phantom{0}1.78$ & $99.47$ / $\phantom{0}3.61$ & $99.49$ / $\phantom{0}3.31$ & $99.69$ / $\phantom{0}2.72$ & $99.62$ / $\phantom{0}2.85$ \\
# AudioClip & $99.05$ / $\phantom{0}4.88$ & $99.94$ / $\phantom{0}1.12$ & $99.80$ / $\phantom{0}2.07$ & $99.64$ / $\phantom{0}3.05$ & $99.61$ / $\phantom{0}2.78$ \\
# Wav2Clip & $99.73$ / $\phantom{0}2.23$ & $100.00$ / $\phantom{0}0.04$ & $100.00$ / $\phantom{0}0.26$ & $98.95$ / $\phantom{0}5.04$ & $99.67$ / $\phantom{0}1.89$ \\
# AASIST & $99.97$ / $\phantom{0}0.68$ & $99.97$ / $\phantom{0}0.65$ & $99.95$ / $\phantom{0}0.98$ & $99.86$ / $\phantom{0}1.72$ & $99.94$ / $\phantom{0}1.01$ \\
# SFATNet & $98.02$ / $\phantom{0}6.71$ & $99.87$ / $\phantom{0}1.53$ & $99.88$ / $\phantom{0}1.73$ & $98.10$ / $\phantom{0}6.92$ & $98.97$ / $\phantom{0}4.22$ \\
# ASDG & $99.93$ / $\phantom{0}0.94$ & $99.93$ / $\phantom{0}0.27$ & $99.91$ / $\phantom{0}1.07$ & $99.68$ / $\phantom{0}1.72$ & $99.86$ / $\phantom{0}1.00$ \\
# Ours/ResNet & $99.94$ / $\phantom{0}0.57$ & $100.00$ / $\phantom{0}0.10$ & $99.99$ / $\phantom{0}0.55$ & $99.98$ / $\phantom{0}0.47$ & $99.98$ / $\phantom{0}0.42$ \\
# Ours/ablations/con_loss_feat/ResNet & nan & nan & nan & $99.99$ / $\phantom{0}0.44$ & $99.99$ / $\phantom{0}0.44$ \\
# Ours/ablations/con_loss_voc/ResNet & nan & nan & nan & $99.98$ / $\phantom{0}0.44$ & $99.98$ / $\phantom{0}0.44$ \\
# Ours/ablations/con_loss_feat_voc/ResNet & nan & nan & nan & $99.99$ / $\phantom{0}0.41$ & $99.99$ / $\phantom{0}0.41$ \\
# Ours/ablations/shuffle_feat/ResNet & nan & nan & nan & $99.98$ / $\phantom{0}0.44$ & $99.98$ / $\phantom{0}0.44$ \\
# Ours/ablations/shuffle_style/ResNet & nan & nan & nan & $99.97$ / $\phantom{0}0.62$ & $99.97$ / $\phantom{0}0.62$ \\
# Ours/ablations/shuffle_style_feat/ResNet & nan & nan & nan & $99.97$ / $\phantom{0}0.72$ & $99.97$ / $\phantom{0}0.72$ \\
# Ours/ablations/one_stem/ResNet & nan & nan & nan & $99.97$ / $\phantom{0}0.74$ & $99.97$ / $\phantom{0}0.74$ \\
# Ours/ablations/use_adversarial_loss/ResNet & nan & nan & nan & $99.99$ / $\phantom{0}0.41$ & $99.99$ / $\phantom{0}0.41$ \\
# \end{tabular}

# %% [markdown]
# ## Cross method

# %% [markdown]
# - "Ours/ablations/con_loss_voc/ResNet": seed 0
# - "Ours/ablations/con_loss_feat_voc/ResNet": seed 0

# %%
# V = 0
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
        "Wave2Vec2": 1,
        "WaveLM": 2,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_method_evaluation(
    models=models,
    versions=versions,
    show_latex=1,
    tasks=["LibriSeVoc_cross_method"],
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>dataset</th>
#       <th colspan="5" halign="left">LibriSeVoc</th>
#     </tr>
#     <tr>
#       <th>method</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>5</th>
#       <th>999</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.38$ / $\phantom{0}3.81$</td>
#       <td>$86.20$ / $21.92$</td>
#       <td>$92.76$ / $14.54$</td>
#       <td>$99.98$ / $\phantom{0}0.53$</td>
#       <td>$94.58$ / $10.20$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$84.55$ / $23.90$</td>
#       <td>$89.71$ / $18.67$</td>
#       <td>$74.78$ / $31.39$</td>
#       <td>$88.05$ / $20.86$</td>
#       <td>$84.27$ / $23.70$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$77.57$ / $29.50$</td>
#       <td>$82.11$ / $25.37$</td>
#       <td>$76.87$ / $30.16$</td>
#       <td>$90.59$ / $17.39$</td>
#       <td>$81.78$ / $25.60$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$94.54$ / $11.14$</td>
#       <td>$99.92$ / $\phantom{0}0.76$</td>
#       <td>$82.14$ / $26.32$</td>
#       <td>$94.58$ / $11.47$</td>
#       <td>$92.80$ / $12.42$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$99.12$ / $\phantom{0}4.39$</td>
#       <td>$99.99$ / $\phantom{0}0.32$</td>
#       <td>$93.38$ / $14.24$</td>
#       <td>$98.98$ / $\phantom{0}4.77$</td>
#       <td>$97.87$ / $\phantom{0}5.93$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$85.15$ / $22.15$</td>
#       <td>$90.84$ / $16.91$</td>
#       <td>$73.76$ / $31.54$</td>
#       <td>$88.19$ / $19.50$</td>
#       <td>$84.48$ / $22.52$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$92.77$ / $15.30$</td>
#       <td>$92.05$ / $15.75$</td>
#       <td>$77.04$ / $28.97$</td>
#       <td>$97.62$ / $\phantom{0}8.48$</td>
#       <td>$89.87$ / $17.12$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$94.10$ / $12.57$</td>
#       <td>$75.71$ / $30.63$</td>
#       <td>$90.18$ / $17.46$</td>
#       <td>$77.33$ / $28.47$</td>
#       <td>$84.33$ / $22.28$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$91.02$ / $16.74$</td>
#       <td>$86.63$ / $20.83$</td>
#       <td>$80.32$ / $27.04$</td>
#       <td>$97.29$ / $\phantom{0}8.25$</td>
#       <td>$88.82$ / $18.21$</td>
#     </tr>
#     <tr>
#       <th>SFATNet</th>
#       <td>$91.90$ / $15.85$</td>
#       <td>$87.87$ / $19.95$</td>
#       <td>$78.19$ / $28.57$</td>
#       <td>$97.64$ / $\phantom{0}7.58$</td>
#       <td>$88.90$ / $17.99$</td>
#     </tr>
#     <tr>
#       <th>ASDG</th>
#       <td>$98.81$ / $\phantom{0}6.36$</td>
#       <td>$75.89$ / $25.71$</td>
#       <td>$79.85$ / $24.99$</td>
#       <td>$99.89$ / $\phantom{0}1.25$</td>
#       <td>$88.61$ / $14.58$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.11$ / $\phantom{0}3.86$</td>
#       <td>$97.28$ / $\phantom{0}7.46$</td>
#       <td>$96.48$ / $\phantom{0}8.33$</td>
#       <td>$99.87$ / $\phantom{0}1.63$</td>
#       <td>$98.19$ / $\phantom{0}5.32$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$99.07$ / $\phantom{0}4.05$</td>
#       <td>$96.98$ / $\phantom{0}8.09$</td>
#       <td>$95.13$ / $10.90$</td>
#       <td>$99.86$ / $\phantom{0}1.67$</td>
#       <td>$97.76$ / $\phantom{0}6.18$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$99.05$ / $\phantom{0}3.80$</td>
#       <td>$95.83$ / $10.43$</td>
#       <td>$96.49$ / $\phantom{0}8.24$</td>
#       <td>$99.75$ / $\phantom{0}1.89$</td>
#       <td>$97.78$ / $\phantom{0}6.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$99.02$ / $\phantom{0}4.24$</td>
#       <td>$94.74$ / $11.98$</td>
#       <td>$96.55$ / $\phantom{0}8.25$</td>
#       <td>$99.80$ / $\phantom{0}1.82$</td>
#       <td>$97.53$ / $\phantom{0}6.57$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$98.82$ / $\phantom{0}5.11$</td>
#       <td>$97.50$ / $\phantom{0}6.55$</td>
#       <td>$95.57$ / $10.11$</td>
#       <td>$99.81$ / $\phantom{0}2.16$</td>
#       <td>$97.92$ / $\phantom{0}5.98$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$98.92$ / $\phantom{0}4.77$</td>
#       <td>$97.26$ / $\phantom{0}7.56$</td>
#       <td>$94.76$ / $11.06$</td>
#       <td>$99.84$ / $\phantom{0}1.82$</td>
#       <td>$97.69$ / $\phantom{0}6.30$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$99.12$ / $\phantom{0}4.35$</td>
#       <td>$97.12$ / $\phantom{0}7.61$</td>
#       <td>$95.74$ / $\phantom{0}9.67$</td>
#       <td>$99.88$ / $\phantom{0}1.40$</td>
#       <td>$97.96$ / $\phantom{0}5.76$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem/ResNet</th>
#       <td>$97.72$ / $\phantom{0}8.25$</td>
#       <td>$93.02$ / $13.10$</td>
#       <td>$86.28$ / $21.32$</td>
#       <td>$99.16$ / $\phantom{0}5.03$</td>
#       <td>$94.04$ / $11.93$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/use_adversarial_loss/ResNet</th>
#       <td>$99.02$ / $\phantom{0}4.22$</td>
#       <td>$95.58$ / $10.37$</td>
#       <td>$95.80$ / $\phantom{0}9.47$</td>
#       <td>$99.82$ / $\phantom{0}1.90$</td>
#       <td>$97.56$ / $\phantom{0}6.49$</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrr}
# dataset & \multicolumn{5}{r}{LibriSeVoc} \\
# method & 1 & 2 & 3 & 5 & 999 \\
# model &  &  &  &  &  \\
# LCNN & $99.38$ / $\phantom{0}3.81$ & $86.20$ / $21.92$ & $92.76$ / $14.54$ & $99.98$ / $\phantom{0}0.53$ & $94.58$ / $10.20$ \\
# RawNet2 & $84.55$ / $23.90$ & $89.71$ / $18.67$ & $74.78$ / $31.39$ & $88.05$ / $20.86$ & $84.27$ / $23.70$ \\
# RawGAT & $77.57$ / $29.50$ & $82.11$ / $25.37$ & $76.87$ / $30.16$ & $90.59$ / $17.39$ & $81.78$ / $25.60$ \\
# Wave2Vec2 & $94.54$ / $11.14$ & $99.92$ / $\phantom{0}0.76$ & $82.14$ / $26.32$ & $94.58$ / $11.47$ & $92.80$ / $12.42$ \\
# WaveLM & $99.12$ / $\phantom{0}4.39$ & $99.99$ / $\phantom{0}0.32$ & $93.38$ / $14.24$ & $98.98$ / $\phantom{0}4.77$ & $97.87$ / $\phantom{0}5.93$ \\
# LibriSeVoc & $85.15$ / $22.15$ & $90.84$ / $16.91$ & $73.76$ / $31.54$ & $88.19$ / $19.50$ & $84.48$ / $22.52$ \\
# AudioClip & $92.77$ / $15.30$ & $92.05$ / $15.75$ & $77.04$ / $28.97$ & $97.62$ / $\phantom{0}8.48$ & $89.87$ / $17.12$ \\
# Wav2Clip & $94.10$ / $12.57$ & $75.71$ / $30.63$ & $90.18$ / $17.46$ & $77.33$ / $28.47$ & $84.33$ / $22.28$ \\
# AASIST & $91.02$ / $16.74$ & $86.63$ / $20.83$ & $80.32$ / $27.04$ & $97.29$ / $\phantom{0}8.25$ & $88.82$ / $18.21$ \\
# SFATNet & $91.90$ / $15.85$ & $87.87$ / $19.95$ & $78.19$ / $28.57$ & $97.64$ / $\phantom{0}7.58$ & $88.90$ / $17.99$ \\
# ASDG & $98.81$ / $\phantom{0}6.36$ & $75.89$ / $25.71$ & $79.85$ / $24.99$ & $99.89$ / $\phantom{0}1.25$ & $88.61$ / $14.58$ \\
# Ours/ResNet & $99.11$ / $\phantom{0}3.86$ & $97.28$ / $\phantom{0}7.46$ & $96.48$ / $\phantom{0}8.33$ & $99.87$ / $\phantom{0}1.63$ & $98.19$ / $\phantom{0}5.32$ \\
# Ours/ablations/con_loss_feat/ResNet & $99.07$ / $\phantom{0}4.05$ & $96.98$ / $\phantom{0}8.09$ & $95.13$ / $10.90$ & $99.86$ / $\phantom{0}1.67$ & $97.76$ / $\phantom{0}6.18$ \\
# Ours/ablations/con_loss_voc/ResNet & $99.05$ / $\phantom{0}3.80$ & $95.83$ / $10.43$ & $96.49$ / $\phantom{0}8.24$ & $99.75$ / $\phantom{0}1.89$ & $97.78$ / $\phantom{0}6.09$ \\
# Ours/ablations/con_loss_feat_voc/ResNet & $99.02$ / $\phantom{0}4.24$ & $94.74$ / $11.98$ & $96.55$ / $\phantom{0}8.25$ & $99.80$ / $\phantom{0}1.82$ & $97.53$ / $\phantom{0}6.57$ \\
# Ours/ablations/shuffle_feat/ResNet & $98.82$ / $\phantom{0}5.11$ & $97.50$ / $\phantom{0}6.55$ & $95.57$ / $10.11$ & $99.81$ / $\phantom{0}2.16$ & $97.92$ / $\phantom{0}5.98$ \\
# Ours/ablations/shuffle_style/ResNet & $98.92$ / $\phantom{0}4.77$ & $97.26$ / $\phantom{0}7.56$ & $94.76$ / $11.06$ & $99.84$ / $\phantom{0}1.82$ & $97.69$ / $\phantom{0}6.30$ \\
# Ours/ablations/shuffle_style_feat/ResNet & $99.12$ / $\phantom{0}4.35$ & $97.12$ / $\phantom{0}7.61$ & $95.74$ / $\phantom{0}9.67$ & $99.88$ / $\phantom{0}1.40$ & $97.96$ / $\phantom{0}5.76$ \\
# Ours/ablations/one_stem/ResNet & $97.72$ / $\phantom{0}8.25$ & $93.02$ / $13.10$ & $86.28$ / $21.32$ & $99.16$ / $\phantom{0}5.03$ & $94.04$ / $11.93$ \\
# Ours/ablations/use_adversarial_loss/ResNet & $99.02$ / $\phantom{0}4.22$ & $95.58$ / $10.37$ & $95.80$ / $\phantom{0}9.47$ & $99.82$ / $\phantom{0}1.90$ & $97.56$ / $\phantom{0}6.49$ \\
# \end{tabular}

# %%
tmp = deepcopy(MODELs_VERSIONS)
tmp.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
        "Wave2Vec2": 1,
        "WaveLM": 0,
    }
)

data = display_cross_method_evaluation(
    models=tmp.keys(),
    versions=tmp.values(),
    show_latex=1,
    tasks=["wavefake_cross_method"],
)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/wavefake_cross_method/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/wavefake_cross_method/version_0/test.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>dataset</th>
#       <th colspan="7" halign="left">wavefake</th>
#     </tr>
#     <tr>
#       <th>method</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>999</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.95$ / $\phantom{0}0.92$</td>
#       <td>$99.92$ / $\phantom{0}1.23$</td>
#       <td>$99.47$ / $\phantom{0}3.51$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.79$ / $\phantom{0}1.93$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.86$ / $\phantom{0}1.31$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$79.06$ / $28.37$</td>
#       <td>$69.98$ / $35.26$</td>
#       <td>$71.32$ / $34.22$</td>
#       <td>$99.89$ / $\phantom{0}1.27$</td>
#       <td>$93.87$ / $13.49$</td>
#       <td>$88.24$ / $20.13$</td>
#       <td>$83.73$ / $22.12$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$99.75$ / $\phantom{0}2.40$</td>
#       <td>$98.68$ / $\phantom{0}5.95$</td>
#       <td>$96.88$ / $\phantom{0}9.20$</td>
#       <td>$100.00$ / $\phantom{0}0.11$</td>
#       <td>$99.86$ / $\phantom{0}1.68$</td>
#       <td>$99.90$ / $\phantom{0}1.26$</td>
#       <td>$99.18$ / $\phantom{0}3.43$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$99.87$ / $\phantom{0}0.76$</td>
#       <td>$99.25$ / $\phantom{0}4.15$</td>
#       <td>$98.47$ / $\phantom{0}6.26$</td>
#       <td>$99.89$ / $\phantom{0}0.19$</td>
#       <td>$99.89$ / $\phantom{0}0.38$</td>
#       <td>$99.88$ / $\phantom{0}0.58$</td>
#       <td>$99.54$ / $\phantom{0}2.06$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#       <td>$99.88$ / $\phantom{0}1.35$</td>
#       <td>$99.30$ / $\phantom{0}4.19$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.42$</td>
#       <td>$100.00$ / $\phantom{0}0.19$</td>
#       <td>$99.86$ / $\phantom{0}1.08$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$87.41$ / $21.22$</td>
#       <td>$69.95$ / $35.33$</td>
#       <td>$79.44$ / $27.89$</td>
#       <td>$99.97$ / $\phantom{0}0.61$</td>
#       <td>$95.55$ / $11.34$</td>
#       <td>$95.32$ / $12.04$</td>
#       <td>$87.94$ / $18.07$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$99.94$ / $\phantom{0}1.13$</td>
#       <td>$99.81$ / $\phantom{0}2.05$</td>
#       <td>$99.43$ / $\phantom{0}3.66$</td>
#       <td>$99.98$ / $\phantom{0}0.78$</td>
#       <td>$98.53$ / $\phantom{0}6.17$</td>
#       <td>$99.98$ / $\phantom{0}0.65$</td>
#       <td>$99.61$ / $\phantom{0}2.40$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$99.94$ / $\phantom{0}0.95$</td>
#       <td>$99.97$ / $\phantom{0}0.63$</td>
#       <td>$99.43$ / $\phantom{0}3.51$</td>
#       <td>$100.00$ / $\phantom{0}0.23$</td>
#       <td>$99.95$ / $\phantom{0}0.90$</td>
#       <td>$99.99$ / $\phantom{0}0.56$</td>
#       <td>$99.88$ / $\phantom{0}1.13$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$99.71$ / $\phantom{0}2.45$</td>
#       <td>$96.62$ / $\phantom{0}9.97$</td>
#       <td>$96.10$ / $10.62$</td>
#       <td>$99.99$ / $\phantom{0}0.34$</td>
#       <td>$99.96$ / $\phantom{0}0.88$</td>
#       <td>$99.97$ / $\phantom{0}0.76$</td>
#       <td>$98.73$ / $\phantom{0}4.17$</td>
#     </tr>
#     <tr>
#       <th>SFATNet</th>
#       <td>$72.79$ / $33.59$</td>
#       <td>$68.23$ / $36.85$</td>
#       <td>$68.22$ / $36.76$</td>
#       <td>$70.27$ / $35.13$</td>
#       <td>$70.57$ / $35.17$</td>
#       <td>$61.50$ / $41.64$</td>
#       <td>$68.60$ / $36.52$</td>
#     </tr>
#     <tr>
#       <th>ASDG</th>
#       <td>$100.00$ / $\phantom{0}1.92$</td>
#       <td>$100.00$ / $\phantom{0}1.34$</td>
#       <td>$100.00$ / $\phantom{0}5.84$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}4.96$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$100.00$ / $\phantom{0}2.35$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.12$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#       <td>$99.89$ / $\phantom{0}1.41$</td>
#       <td>$100.00$ / $\phantom{0}0.03$</td>
#       <td>$100.00$ / $\phantom{0}0.06$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.98$ / $\phantom{0}0.32$</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrr}
# dataset & \multicolumn{7}{r}{wavefake} \\
# method & 2 & 3 & 4 & 5 & 6 & 7 & 999 \\
# model &  &  &  &  &  &  &  \\
# LCNN & $99.95$ / $\phantom{0}0.92$ & $99.92$ / $\phantom{0}1.23$ & $99.47$ / $\phantom{0}3.51$ & $100.00$ / $\phantom{0}0.08$ & $99.79$ / $\phantom{0}1.93$ & $100.00$ / $\phantom{0}0.18$ & $99.86$ / $\phantom{0}1.31$ \\
# RawNet2 & $79.06$ / $28.37$ & $69.98$ / $35.26$ & $71.32$ / $34.22$ & $99.89$ / $\phantom{0}1.27$ & $93.87$ / $13.49$ & $88.24$ / $20.13$ & $83.73$ / $22.12$ \\
# RawGAT & $99.75$ / $\phantom{0}2.40$ & $98.68$ / $\phantom{0}5.95$ & $96.88$ / $\phantom{0}9.20$ & $100.00$ / $\phantom{0}0.11$ & $99.86$ / $\phantom{0}1.68$ & $99.90$ / $\phantom{0}1.26$ & $99.18$ / $\phantom{0}3.43$ \\
# Wave2Vec2 & $99.87$ / $\phantom{0}0.76$ & $99.25$ / $\phantom{0}4.15$ & $98.47$ / $\phantom{0}6.26$ & $99.89$ / $\phantom{0}0.19$ & $99.89$ / $\phantom{0}0.38$ & $99.88$ / $\phantom{0}0.58$ & $99.54$ / $\phantom{0}2.06$ \\
# WaveLM & $99.99$ / $\phantom{0}0.27$ & $99.88$ / $\phantom{0}1.35$ & $99.30$ / $\phantom{0}4.19$ & $100.00$ / $\phantom{0}0.08$ & $99.99$ / $\phantom{0}0.42$ & $100.00$ / $\phantom{0}0.19$ & $99.86$ / $\phantom{0}1.08$ \\
# LibriSeVoc & $87.41$ / $21.22$ & $69.95$ / $35.33$ & $79.44$ / $27.89$ & $99.97$ / $\phantom{0}0.61$ & $95.55$ / $11.34$ & $95.32$ / $12.04$ & $87.94$ / $18.07$ \\
# AudioClip & $99.94$ / $\phantom{0}1.13$ & $99.81$ / $\phantom{0}2.05$ & $99.43$ / $\phantom{0}3.66$ & $99.98$ / $\phantom{0}0.78$ & $98.53$ / $\phantom{0}6.17$ & $99.98$ / $\phantom{0}0.65$ & $99.61$ / $\phantom{0}2.40$ \\
# Wav2Clip & $99.94$ / $\phantom{0}0.95$ & $99.97$ / $\phantom{0}0.63$ & $99.43$ / $\phantom{0}3.51$ & $100.00$ / $\phantom{0}0.23$ & $99.95$ / $\phantom{0}0.90$ & $99.99$ / $\phantom{0}0.56$ & $99.88$ / $\phantom{0}1.13$ \\
# AASIST & $99.71$ / $\phantom{0}2.45$ & $96.62$ / $\phantom{0}9.97$ & $96.10$ / $10.62$ & $99.99$ / $\phantom{0}0.34$ & $99.96$ / $\phantom{0}0.88$ & $99.97$ / $\phantom{0}0.76$ & $98.73$ / $\phantom{0}4.17$ \\
# SFATNet & $72.79$ / $33.59$ & $68.23$ / $36.85$ & $68.22$ / $36.76$ & $70.27$ / $35.13$ & $70.57$ / $35.17$ & $61.50$ / $41.64$ & $68.60$ / $36.52$ \\
# ASDG & $100.00$ / $\phantom{0}1.92$ & $100.00$ / $\phantom{0}1.34$ & $100.00$ / $\phantom{0}5.84$ & $100.00$ / $\phantom{0}0.00$ & $100.00$ / $\phantom{0}4.96$ & $100.00$ / $\phantom{0}0.01$ & $100.00$ / $\phantom{0}2.35$ \\
# Ours/ResNet & $100.00$ / $\phantom{0}0.12$ & $99.99$ / $\phantom{0}0.27$ & $99.89$ / $\phantom{0}1.41$ & $100.00$ / $\phantom{0}0.03$ & $100.00$ / $\phantom{0}0.06$ & $100.00$ / $\phantom{0}0.00$ & $99.98$ / $\phantom{0}0.32$ \\
# \end{tabular}

# %% [markdown]
# ## Cross Dataset

# %% [markdown]
# - version 2: seed is 1
# - con_loss_feat_voc/ResNet": seed 2
# - - con_loss_feat/ResNet": seed 1

# %%
V = 1
tmp = deepcopy(MODELs_VERSIONS)
tmp.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
        "Wave2Vec2": 0,
        "WaveLM": 0,
    }
)

data = display_cross_dataset_evaluation(
    models=tmp.keys(),
    versions=tmp.values(),
    show_latex=1,
    tasks=[
        "LibriSeVoc_cross_dataset",
        # "DECRO_chinese",
        # "DECRO_english",
    ],
    only_LibriSeVoc=False,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>avg</th>
#       <th>ch</th>
#       <th>en</th>
#       <th>inTheWild</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$100.00$ / $\phantom{0}0.14$</td>
#       <td>$95.00$ / $12.30$</td>
#       <td>$96.27$ / $10.37$</td>
#       <td>$96.87$ / $\phantom{0}9.40$</td>
#       <td>$97.03$ / $\phantom{0}9.12$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#       <td>$99.98$ / $\phantom{0}0.53$</td>
#       <td>$97.88$ / $\phantom{0}5.99$</td>
#       <td>$79.70$ / $26.63$</td>
#       <td>$63.56$ / $40.36$</td>
#       <td>$41.19$ / $57.62$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$99.72$ / $\phantom{0}2.33$</td>
#       <td>$79.98$ / $27.74$</td>
#       <td>$89.97$ / $18.60$</td>
#       <td>$69.27$ / $36.15$</td>
#       <td>$79.50$ / $28.11$</td>
#       <td>$97.27$ / $\phantom{0}8.55$</td>
#       <td>$99.98$ / $\phantom{0}0.61$</td>
#       <td>$87.95$ / $17.44$</td>
#       <td>$64.68$ / $39.65$</td>
#       <td>$45.59$ / $53.70$</td>
#       <td>$88.92$ / $19.83$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$100.00$ / $\phantom{0}0.16$</td>
#       <td>$88.56$ / $19.88$</td>
#       <td>$98.56$ / $\phantom{0}6.12$</td>
#       <td>$87.74$ / $20.54$</td>
#       <td>$87.62$ / $20.64$</td>
#       <td>$99.88$ / $\phantom{0}1.34$</td>
#       <td>$100.00$ / $\phantom{0}0.20$</td>
#       <td>$94.62$ / $\phantom{0}9.84$</td>
#       <td>$75.35$ / $33.05$</td>
#       <td>$76.87$ / $30.09$</td>
#       <td>$94.16$ / $12.78$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$59.08$ / $43.60$</td>
#       <td>$43.60$ / $54.47$</td>
#       <td>$51.31$ / $49.14$</td>
#       <td>$50.24$ / $49.75$</td>
#       <td>$61.07$ / $42.33$</td>
#       <td>$55.58$ / $45.98$</td>
#       <td>$85.62$ / $22.63$</td>
#       <td>$58.07$ / $43.99$</td>
#       <td>$73.60$ / $32.58$</td>
#       <td>$94.24$ / $10.99$</td>
#       <td>$62.40$ / $39.55$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$91.85$ / $15.98$</td>
#       <td>$74.63$ / $32.18$</td>
#       <td>$83.42$ / $24.79$</td>
#       <td>$72.25$ / $33.89$</td>
#       <td>$67.80$ / $37.11$</td>
#       <td>$90.94$ / $17.16$</td>
#       <td>$88.07$ / $20.13$</td>
#       <td>$81.28$ / $25.89$</td>
#       <td>$68.21$ / $32.84$</td>
#       <td>$57.37$ / $45.92$</td>
#       <td>$87.28$ / $20.38$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$99.73$ / $\phantom{0}2.19$</td>
#       <td>$76.05$ / $30.42$</td>
#       <td>$89.35$ / $18.39$</td>
#       <td>$68.04$ / $36.34$</td>
#       <td>$78.75$ / $28.21$</td>
#       <td>$98.53$ / $\phantom{0}6.03$</td>
#       <td>$99.96$ / $\phantom{0}0.91$</td>
#       <td>$87.20$ / $17.50$</td>
#       <td>$70.14$ / $35.51$</td>
#       <td>$48.73$ / $51.15$</td>
#       <td>$89.84$ / $18.05$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$99.38$ / $\phantom{0}2.97$</td>
#       <td>$81.52$ / $25.01$</td>
#       <td>$97.45$ / $\phantom{0}6.02$</td>
#       <td>$90.17$ / $15.53$</td>
#       <td>$93.74$ / $10.92$</td>
#       <td>$99.08$ / $\phantom{0}3.55$</td>
#       <td>$99.15$ / $\phantom{0}3.57$</td>
#       <td>$94.36$ / $\phantom{0}9.65$</td>
#       <td>$69.20$ / $35.93$</td>
#       <td>$70.56$ / $32.30$</td>
#       <td>$69.88$ / $35.93$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$99.99$ / $\phantom{0}0.39$</td>
#       <td>$96.03$ / $10.79$</td>
#       <td>$99.70$ / $\phantom{0}2.48$</td>
#       <td>$98.58$ / $\phantom{0}5.97$</td>
#       <td>$98.92$ / $\phantom{0}5.02$</td>
#       <td>$99.91$ / $\phantom{0}1.31$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.02$ / $\phantom{0}3.73$</td>
#       <td>$85.78$ / $21.69$</td>
#       <td>$73.25$ / $33.53$</td>
#       <td>$29.53$ / $66.58$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$91.56$ / $16.57$</td>
#       <td>$98.72$ / $\phantom{0}5.64$</td>
#       <td>$90.12$ / $18.26$</td>
#       <td>$91.22$ / $17.10$</td>
#       <td>$100.00$ / $\phantom{0}0.16$</td>
#       <td>$99.99$ / $\phantom{0}0.40$</td>
#       <td>$95.94$ / $\phantom{0}8.31$</td>
#       <td>$84.49$ / $24.65$</td>
#       <td>$76.13$ / $31.99$</td>
#       <td>$95.16$ / $12.37$</td>
#     </tr>
#     <tr>
#       <th>SFATNet</th>
#       <td>$90.27$ / $18.49$</td>
#       <td>$90.11$ / $18.87$</td>
#       <td>$81.40$ / $26.82$</td>
#       <td>$72.07$ / $35.01$</td>
#       <td>$75.69$ / $31.78$</td>
#       <td>$85.85$ / $22.74$</td>
#       <td>$99.08$ / $\phantom{0}4.56$</td>
#       <td>$84.92$ / $22.61$</td>
#       <td>$64.19$ / $38.04$</td>
#       <td>$56.53$ / $46.55$</td>
#       <td>$46.03$ / $52.46$</td>
#     </tr>
#     <tr>
#       <th>ASDG</th>
#       <td>$99.85$ / $\phantom{0}1.69$</td>
#       <td>$83.63$ / $24.41$</td>
#       <td>$90.12$ / $17.46$</td>
#       <td>$91.30$ / $16.45$</td>
#       <td>$92.69$ / $14.93$</td>
#       <td>$99.97$ / $\phantom{0}0.50$</td>
#       <td>$99.97$ / $\phantom{0}0.56$</td>
#       <td>$93.93$ / $10.86$</td>
#       <td>$72.22$ / $31.11$</td>
#       <td>$52.07$ / $50.02$</td>
#       <td>$41.24$ / $55.72$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.22$</td>
#       <td>$99.65$ / $\phantom{0}2.73$</td>
#       <td>$98.82$ / $\phantom{0}5.33$</td>
#       <td>$99.57$ / $\phantom{0}3.07$</td>
#       <td>$99.32$ / $\phantom{0}3.90$</td>
#       <td>$99.92$ / $\phantom{0}0.97$</td>
#       <td>$100.00$ / $\phantom{0}0.07$</td>
#       <td>$99.61$ / $\phantom{0}2.33$</td>
#       <td>$89.06$ / $16.93$</td>
#       <td>$99.24$ / $\phantom{0}3.93$</td>
#       <td>$34.13$ / $63.53$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$99.48$ / $\phantom{0}3.44$</td>
#       <td>$96.60$ / $\phantom{0}9.62$</td>
#       <td>$99.35$ / $\phantom{0}3.89$</td>
#       <td>$98.92$ / $\phantom{0}5.11$</td>
#       <td>$99.95$ / $\phantom{0}0.79$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.19$ / $\phantom{0}3.31$</td>
#       <td>$88.05$ / $17.56$</td>
#       <td>$99.07$ / $\phantom{0}4.50$</td>
#       <td>$29.66$ / $66.92$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.37$</td>
#       <td>$99.37$ / $\phantom{0}3.70$</td>
#       <td>$99.10$ / $\phantom{0}4.47$</td>
#       <td>$99.33$ / $\phantom{0}3.95$</td>
#       <td>$99.22$ / $\phantom{0}4.32$</td>
#       <td>$99.90$ / $\phantom{0}1.20$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.56$ / $\phantom{0}2.58$</td>
#       <td>$90.94$ / $15.86$</td>
#       <td>$98.15$ / $\phantom{0}6.52$</td>
#       <td>$47.07$ / $52.72$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$99.99$ / $\phantom{0}0.33$</td>
#       <td>$97.69$ / $\phantom{0}7.57$</td>
#       <td>$98.30$ / $\phantom{0}6.28$</td>
#       <td>$98.37$ / $\phantom{0}6.19$</td>
#       <td>$98.28$ / $\phantom{0}6.29$</td>
#       <td>$99.91$ / $\phantom{0}1.24$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$98.93$ / $\phantom{0}4.00$</td>
#       <td>$85.14$ / $21.79$</td>
#       <td>$95.50$ / $10.41$</td>
#       <td>$36.22$ / $61.27$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.25$</td>
#       <td>$98.06$ / $\phantom{0}6.92$</td>
#       <td>$98.45$ / $\phantom{0}5.86$</td>
#       <td>$98.32$ / $\phantom{0}6.23$</td>
#       <td>$98.00$ / $\phantom{0}6.79$</td>
#       <td>$99.97$ / $\phantom{0}0.71$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$98.97$ / $\phantom{0}3.83$</td>
#       <td>$82.11$ / $24.00$</td>
#       <td>$94.49$ / $12.44$</td>
#       <td>$62.83$ / $41.10$</td>
#     </tr>
#     <tr>
#       <th>Ours/abla
# \begin{tabular}{lrr}
# method & 0 & 1 & 2 & 3 & 4 & 5 & 6 & avg & ch & en & inTheWild \\
# model &  &  &  &  &  &  &  &  &  &  &  \\
# LCNN & $100.00$ / $\phantom{0}0.14$ & $95.00$ / $12.30$ & $96.27$ / $10.37$ & $96.87$ / $\phantom{0}9.40$ & $97.03$ / $\phantom{0}9.12$ & $100.00$ / $\phantom{0}0.09$ & $99.98$ / $\phantom{0}0.53$ & $97.88$ / $\phantom{0}5.99$ & $79.70$ / $26.63$ & $63.56$ / $40.36$ & $41.19$ / $57.62$ \\
# RawNet2 & $99.72$ / $\phantom{0}2.33$ & $79.98$ / $27.74$ & $89.97$ / $18.60$ & $69.27$ / $36.15$ & $79.50$ / $28.11$ & $97.27$ / $\phantom{0}8.55$ & $99.98$ / $\phantom{0}0.61$ & $87.95$ / $17.44$ & $64.68$ / $39.65$ & $45.59$ / $53.70$ & $88.92$ / $19.83$ \\
# RawGAT & $100.00$ / $\phantom{0}0.16$ & $88.56$ / $19.88$ & $98.56$ / $\phantom{0}6.12$ & $87.74$ / $20.54$ & $87.62$ / $20.64$ & $99.88$ / $\phantom{0}1.34$ & $100.00$ / $\phantom{0}0.20$ & $94.62$ / $\phantom{0}9.84$ & $75.35$ / $33.05$ & $76.87$ / $30.09$ & $94.16$ / $12.78$ \\
# Wave2Vec2 & $59.08$ / $43.60$ & $43.60$ / $54.47$ & $51.31$ / $49.14$ & $50.24$ / $49.75$ & $61.07$ / $42.33$ & $55.58$ / $45.98$ & $85.62$ / $22.63$ & $58.07$ / $43.99$ & $73.60$ / $32.58$ & $94.24$ / $10.99$ & $62.40$ / $39.55$ \\
# WaveLM & $91.85$ / $15.98$ & $74.63$ / $32.18$ & $83.42$ / $24.79$ & $72.25$ / $33.89$ & $67.80$ / $37.11$ & $90.94$ / $17.16$ & $88.07$ / $20.13$ & $81.28$ / $25.89$ & $68.21$ / $32.84$ & $57.37$ / $45.92$ & $87.28$ / $20.38$ \\
# LibriSeVoc & $99.73$ / $\phantom{0}2.19$ & $76.05$ / $30.42$ & $89.35$ / $18.39$ & $68.04$ / $36.34$ & $78.75$ / $28.21$ & $98.53$ / $\phantom{0}6.03$ & $99.96$ / $\phantom{0}0.91$ & $87.20$ / $17.50$ & $70.14$ / $35.51$ & $48.73$ / $51.15$ & $89.84$ / $18.05$ \\
# AudioClip & $99.38$ / $\phantom{0}2.97$ & $81.52$ / $25.01$ & $97.45$ / $\phantom{0}6.02$ & $90.17$ / $15.53$ & $93.74$ / $10.92$ & $99.08$ / $\phantom{0}3.55$ & $99.15$ / $\phantom{0}3.57$ & $94.36$ / $\phantom{0}9.65$ & $69.20$ / $35.93$ & $70.56$ / $32.30$ & $69.88$ / $35.93$ \\
# Wav2Clip & $99.99$ / $\phantom{0}0.39$ & $96.03$ / $10.79$ & $99.70$ / $\phantom{0}2.48$ & $98.58$ / $\phantom{0}5.97$ & $98.92$ / $\phantom{0}5.02$ & $99.91$ / $\phantom{0}1.31$ & $100.00$ / $\phantom{0}0.18$ & $99.02$ / $\phantom{0}3.73$ & $85.78$ / $21.69$ & $73.25$ / $33.53$ & $29.53$ / $66.58$ \\
# AASIST & $100.00$ / $\phantom{0}0.05$ & $91.56$ / $16.57$ & $98.72$ / $\phantom{0}5.64$ & $90.12$ / $18.26$ & $91.22$ / $17.10$ & $100.00$ / $\phantom{0}0.16$ & $99.99$ / $\phantom{0}0.40$ & $95.94$ / $\phantom{0}8.31$ & $84.49$ / $24.65$ & $76.13$ / $31.99$ & $95.16$ / $12.37$ \\
# SFATNet & $90.27$ / $18.49$ & $90.11$ / $18.87$ & $81.40$ / $26.82$ & $72.07$ / $35.01$ & $75.69$ / $31.78$ & $85.85$ / $22.74$ & $99.08$ / $\phantom{0}4.56$ & $84.92$ / $22.61$ & $64.19$ / $38.04$ & $56.53$ / $46.55$ & $46.03$ / $52.46$ \\
# ASDG & $99.85$ / $\phantom{0}1.69$ & $83.63$ / $24.41$ & $90.12$ / $17.46$ & $91.30$ / $16.45$ & $92.69$ / $14.93$ & $99.97$ / $\phantom{0}0.50$ & $99.97$ / $\phantom{0}0.56$ & $93.93$ / $10.86$ & $72.22$ / $31.11$ & $52.07$ / $50.02$ & $41.24$ / $55.72$ \\
# Ours/ResNet & $99.99$ / $\phantom{0}0.22$ & $99.65$ / $\phantom{0}2.73$ & $98.82$ / $\phantom{0}5.33$ & $99.57$ / $\phantom{0}3.07$ & $99.32$ / $\phantom{0}3.90$ & $99.92$ / $\phantom{0}0.97$ & $100.00$ / $\phantom{0}0.07$ & $99.61$ / $\phantom{0}2.33$ & $89.06$ / $16.93$ & $99.24$ / $\phantom{0}3.93$ & $34.13$ / $63.53$ \\
# Ours/ablations/con_loss_feat/ResNet & $100.00$ / $\phantom{0}0.15$ & $99.48$ / $\phantom{0}3.44$ & $96.60$ / $\phantom{0}9.62$ & $99.35$ / $\phantom{0}3.89$ & $98.92$ / $\phantom{0}5.11$ & $99.95$ / $\phantom{0}0.79$ & $100.00$ / $\phantom{0}0.18$ & $99.19$ / $\phantom{0}3.31$ & $88.05$ / $17.56$ & $99.07$ / $\phantom{0}4.50$ & $29.66$ / $66.92$ \\
# Ours/ablations/con_loss_voc/ResNet & $99.99$ / $\phantom{0}0.37$ & $99.37$ / $\phantom{0}3.70$ & $99.10$ / $\phantom{0}4.47$ & $99.33$ / $\phantom{0}3.95$ & $99.22$ / $\phantom{0}4.32$ & $99.90$ / $\phantom{0}1.20$ & $100.00$ / $\phantom{0}0.08$ & $99.56$ / $\phantom{0}2.58$ & $90.94$ / $15.86$ & $98.15$ / $\phantom{0}6.52$ & $47.07$ / $52.72$ \\
# Ours/ablations/con_loss_feat_voc/ResNet & $99.99$ / $\phantom{0}0.33$ & $97.69$ / $\phantom{0}7.57$ & $98.30$ / $\phantom{0}6.28$ & $98.37$ / $\phantom{0}6.19$ & $98.28$ / $\phantom{0}6.29$ & $99.91$ / $\phantom{0}1.24$ & $100.00$ / $\phantom{0}0.08$ & $98.93$ / $\phantom{0}4.00$ & $85.14$ / $21.79$ & $95.50$ / $10.41$ & $36.22$ / $61.27$ \\
# Ours/ablations/shuffle_feat/ResNet & $100.00$ / $\phantom{0}0.25$ & $98.06$ / $\phantom{0}6.92$ & $98.45$ / $\phantom{0}5.86$ & $98.32$ / $\phantom{0}6.23$ & $98.00$ / $\phantom{0}6.79$ & $99.97$ / $\phantom{0}0.71$ & $100.00$ / $\phantom{0}0.04$ & $98.97$ / $\phantom{0}3.83$ & $82.11$ / $24.00$ & $94.49$ / $12.44$ & $62.83$ / $41.10$ \\
# Ours/ablations/shuffle_style/ResNet & $99.97$ / $\phantom{0}0.45$ & $99.41$ / $\phantom{0}3.87$ & $97.69$ / $\phantom{0}7.73$ & $98.78$ / $\phantom{0}5.47$ & $98.56$ / $\phantom{0}5.95$ & $99.85$ / $\phantom{0}1.34$ & $100.00$ / $\phantom{0}0.08$ & $99.18$ / $\phantom{0}3.56$ & $89.17$ / $16.84$ & $98.23$ / $\phantom{0}6.32$ & $32.42$ / $63.88$ \\
# Ours/ablations/shuffle_style_feat/ResNet & $99.99$ / $\phantom{0}0.32$ & $97.56$ / $\phantom{0}7.85$ & $98.04$ / $\phantom{0}6.74$ & $98.21$ / $\phantom{0}6.48$ & $97.76$ / $\phantom{0}7.15$ & $99.97$ / $\phantom{0}0.72$ & $100.00$ / $\phantom{0}0.05$ & $98.79$ / $\phantom{0}4.19$ & $84.22$ / $22.25$ & $95.11$ / $11.75$ & $63.07$ / $40.57$ \\
# Ours/ablations/one_stem/ResNet & $99.99$ / $\phantom{0}0.20$ & $92.56$ / $14.85$ & $92.74$ / $14.09$ & $90.10$ / $17.75$ & $89.48$ / $17.82$ & $99.94$ / $\phantom{0}0.67$ & $100.00$ / $\phantom{0}0.09$ & $94.97$ / $\phantom{0}9.35$ & $84.98$ / $22.41$ & $85.29$ / $21.76$ & $77.46$ / $28.99$ \\
# Ours/ablations/use_adversarial_loss/ResNet & $99.99$ / $\phantom{0}0.31$ & $99.13$ / $\phantom{0}4.51$ & $98.65$ / $\phantom{0}5.82$ & $99.20$ / $\phantom{0}4.40$ & $99.04$ / $\phantom{0}4.89$ & $99.93$ / $\phantom{0}1.03$ & $100.00$ / $\phantom{0}0.13$ & $99.42$ / $\phantom{0}3.01$ & $89.68$ / $16.91$ & $98.12$ / $\phantom{0}6.91$ & $47.80$ / $52.29$ \\
# \end{tabular}

# %% [markdown]
# ## Cross Language

# %% [markdown]
# - wavefake: seed 22
# - DECRO chinese: seed 7
# - - DECRO chinese: seed 7

# %%
V = 1
tmp = deepcopy(MODELs_VERSIONS)
tmp.update(
    {
        "Ours/ResNet": 0,
        "Ours/ablations/con_loss_voc/ResNet": 0,
        "Ours/ablations/con_loss_feat_voc/ResNet": 0,
        "Wave2Vec2": 0,
        "WaveLM": 0,
    }
)
models = tmp.keys()
versions = tmp.values()
data = display_cross_language_evaluation(models=models, versions=versions, show_latex=1, auc=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_voc/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/con_loss_feat_voc/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/shuffle_style_feat/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/one_stem/ResNet/DECRO_english/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/wavefake_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Ours/ablations/use_adversarial_loss/ResNet/DECRO_english/version_0/test.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>wavefake_cross_lang</th>
#       <th>DECRO_chinese</th>
#       <th>DECRO_english</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$\phantom{0}2.90$</td>
#       <td>$43.62$</td>
#       <td>$36.46$</td>
#       <td>$27.66$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$33.69$</td>
#       <td>$47.08$</td>
#       <td>$47.80$</td>
#       <td>$42.86$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$14.39$</td>
#       <td>$41.14$</td>
#       <td>$47.88$</td>
#       <td>$34.47$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$45.26$</td>
#       <td>$46.02$</td>
#       <td>$29.33$</td>
#       <td>$40.20$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$42.92$</td>
#       <td>$43.40$</td>
#       <td>$44.41$</td>
#       <td>$43.58$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$32.94$</td>
#       <td>$41.33$</td>
#       <td>$46.58$</td>
#       <td>$40.28$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$52.54$</td>
#       <td>$46.40$</td>
#       <td>$52.10$</td>
#       <td>$50.35$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$23.88$</td>
#       <td>$37.07$</td>
#       <td>$22.75$</td>
#       <td>$27.90$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$11.78$</td>
#       <td>$41.49$</td>
#       <td>$46.34$</td>
#       <td>$33.20$</td>
#     </tr>
#     <tr>
#       <th>SFATNet</th>
#       <td>$36.38$</td>
#       <td>$26.36$</td>
#       <td>$31.36$</td>
#       <td>$31.37$</td>
#     </tr>
#     <tr>
#       <th>ASDG</th>
#       <td>$\phantom{0}8.19$</td>
#       <td>$41.43$</td>
#       <td>$41.51$</td>
#       <td>$30.38$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$18.06$</td>
#       <td>$11.36$</td>
#       <td>$37.31$</td>
#       <td>$22.24$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>NaN</td>
#       <td>$14.03$</td>
#       <td>NaN</td>
#       <td>$14.03$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>NaN</td>
#       <td>$12.80$</td>
#       <td>NaN</td>
#       <td>$12.80$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>NaN</td>
#       <td>$11.61$</td>
#       <td>NaN</td>
#       <td>$11.61$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>NaN</td>
#       <td>$21.97$</td>
#       <td>NaN</td>
#       <td>$21.97$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>NaN</td>
#       <td>$15.95$</td>
#       <td>NaN</td>
#       <td>$15.95$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>NaN</td>
#       <td>$29.20$</td>
#       <td>NaN</td>
#       <td>$29.20$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/one_stem/ResNet</th>
#       <td>NaN</td>
#       <td>$38.46$</td>
#       <td>NaN</td>
#       <td>$38.46$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/use_adversarial_loss/ResNet</th>
#       <td>NaN</td>
#       <td>$13.79$</td>
#       <td>NaN</td>
#       <td>$13.79$</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrr}
#  & wavefake_cross_lang & DECRO_chinese & DECRO_english & mean \\
# model &  &  &  &  \\
# LCNN & $\phantom{0}2.90$ & $43.62$ & $36.46$ & $27.66$ \\
# RawNet2 & $33.69$ & $47.08$ & $47.80$ & $42.86$ \\
# RawGAT & $14.39$ & $41.14$ & $47.88$ & $34.47$ \\
# Wave2Vec2 & $45.26$ & $46.02$ & $29.33$ & $40.20$ \\
# WaveLM & $42.92$ & $43.40$ & $44.41$ & $43.58$ \\
# LibriSeVoc & $32.94$ & $41.33$ & $46.58$ & $40.28$ \\
# AudioClip & $52.54$ & $46.40$ & $52.10$ & $50.35$ \\
# Wav2Clip & $23.88$ & $37.07$ & $22.75$ & $27.90$ \\
# AASIST & $11.78$ & $41.49$ & $46.34$ & $33.20$ \\
# SFATNet & $36.38$ & $26.36$ & $31.36$ & $31.37$ \\
# ASDG & $\phantom{0}8.19$ & $41.43$ & $41.51$ & $30.38$ \\
# Ours/ResNet & $18.06$ & $11.36$ & $37.31$ & $22.24$ \\
# Ours/ablations/con_loss_feat/ResNet & nan & $14.03$ & nan & $14.03$ \\
# Ours/ablations/con_loss_voc/ResNet & nan & $12.80$ & nan & $12.80$ \\
# Ours/ablations/con_loss_feat_voc/ResNet & nan & $11.61$ & nan & $11.61$ \\
# Ours/ablations/shuffle_feat/ResNet & nan & $21.97$ & nan & $21.97$ \\
# Ours/ablations/shuffle_style/ResNet & nan & $15.95$ & nan & $15.95$ \\
# Ours/ablations/shuffle_style_feat/ResNet & nan & $29.20$ & nan & $29.20$ \\
# Ours/ablations/one_stem/ResNet & nan & $38.46$ & nan & $38.46$ \\
# Ours/ablations/use_adversarial_loss/ResNet & nan & $13.79$ & nan & $13.79$ \\
# \end{tabular}

# %% [markdown]
# # ASVspoof

# %%
from utils import (
    Display_ASV2019_LA_evaluation,
    Display_ASV2021_evaluation,
    Display_ASV2021_LA_evaluation,
)

# %% [markdown]
# train on ASV2019 LA, but test on
# 1. ASV2019 LA test split
# 2. ASV2021 whole test split
# 3. ASV2021 test splits on five categorys
#     - neural_vocoder_autoregressive
#     - neural_vocoder_nonautoregressive
#     - traditional_vocoder
#     - unknown
#     - waveform_concatenation

# %%
_MODELs_VERSIONS = deepcopy(MODELs_VERSIONS)
_MODELs_VERSIONS.update(
    {
        "Wave2Vec2": range(15),
        "WaveLM": 0,
        "RawGAT": 3,
        "Ours/ResNet": [0, 1, 2, 3, 4],
    }
)
res = Display_ASV2021_evaluation(
    models=_MODELs_VERSIONS.keys(), versions=_MODELs_VERSIONS.values(), task="ASV2021_inner", auc=0, acc=0, calc_avg=False
)
res.display(show_latex=1)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_5/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_7/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_8/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_11/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_12/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_13/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_14/test.csv
