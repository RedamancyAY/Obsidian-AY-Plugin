# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import (
    display_cross_dataset_evaluation,
    display_cross_language_evaluation,
    display_cross_method_evaluation,
    display_inner_evaluation,
)

# %%
MODELs_VERSIONS = {
    "LCNN": 0,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "Ours/ResNet": 0,
    "Ours/ablations/con_loss_feat/ResNet": 0,
    "Ours/ablations/con_loss_voc/ResNet": 0,
    "Ours/ablations/con_loss_feat_voc/ResNet": 0,
    "Ours/ablations/shuffle_feat/ResNet": 0,
    "Ours/ablations/shuffle_style/ResNet": 0,
    "Ours/ablations/shuffle_style_feat/ResNet": 0,
    "Ours/ablations/shuffle_style_feat_con_loss_feat_voc/ResNet": 0,
    "Ours/ablations/shuffle_feat_con_loss_voc/ResNet": 0,
    "Ours/ablations/shuffle_style_con_loss_voc/ResNet": 0,
    "Ours/ablations/shuffle_style_feat_con_loss_voc/ResNet": 0,
    # "Ours/ablations/one_stem/ResNet": 0,
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

# %% [markdown]
# # Inner evaluation

# %%
V = 0
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()


data = display_inner_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LibriSeVoc_inner</th>
#       <th>wavefake_inner</th>
#       <th>DECRO_english</th>
#       <th>DECRO_chinese</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.99$ / $\phantom{0}0.49$</td>
#       <td>$99.99$ / $\phantom{0}0.38$</td>
#       <td>$99.96$ / $\phantom{0}0.90$</td>
#       <td>$99.91$ / $\phantom{0}1.41$</td>
#       <td>$99.96$ / $\phantom{0}0.80$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$99.80$ / $\phantom{0}2.12$</td>
#       <td>$97.56$ / $\phantom{0}8.32$</td>
#       <td>$99.31$ / $\phantom{0}3.73$</td>
#       <td>$98.85$ / $\phantom{0}5.54$</td>
#       <td>$98.88$ / $\phantom{0}4.93$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$99.98$ / $\phantom{0}0.64$</td>
#       <td>$99.98$ / $\phantom{0}0.61$</td>
#       <td>$99.94$ / $\phantom{0}1.29$</td>
#       <td>$99.88$ / $\phantom{0}1.60$</td>
#       <td>$99.95$ / $\phantom{0}1.04$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$99.94$ / $\phantom{0}0.92$</td>
#       <td>$99.95$ / $\phantom{0}1.13$</td>
#       <td>$99.95$ / $\phantom{0}0.99$</td>
#       <td>$99.86$ / $\phantom{0}0.88$</td>
#       <td>$99.93$ / $\phantom{0}0.98$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$99.86$ / $\phantom{0}1.46$</td>
#       <td>$99.95$ / $\phantom{0}1.09$</td>
#       <td>$99.92$ / $\phantom{0}1.48$</td>
#       <td>$99.85$ / $\phantom{0}1.21$</td>
#       <td>$99.89$ / $\phantom{0}1.31$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$99.84$ / $\phantom{0}1.78$</td>
#       <td>$99.47$ / $\phantom{0}3.61$</td>
#       <td>$99.49$ / $\phantom{0}3.31$</td>
#       <td>$99.69$ / $\phantom{0}2.72$</td>
#       <td>$99.62$ / $\phantom{0}2.85$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$99.05$ / $\phantom{0}4.88$</td>
#       <td>$99.94$ / $\phantom{0}1.12$</td>
#       <td>$99.80$ / $\phantom{0}2.07$</td>
#       <td>$99.64$ / $\phantom{0}3.05$</td>
#       <td>$99.61$ / $\phantom{0}2.78$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$99.73$ / $\phantom{0}2.23$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.26$</td>
#       <td>$98.95$ / $\phantom{0}5.04$</td>
#       <td>$99.67$ / $\phantom{0}1.89$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$99.97$ / $\phantom{0}0.68$</td>
#       <td>$99.97$ / $\phantom{0}0.65$</td>
#       <td>$99.95$ / $\phantom{0}0.98$</td>
#       <td>$99.86$ / $\phantom{0}1.72$</td>
#       <td>$99.94$ / $\phantom{0}1.01$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.48$</td>
#       <td>$99.99$ / $\phantom{0}0.37$</td>
#       <td>$99.99$ / $\phantom{0}0.23$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.33$</td>
#       <td>$99.98$ / $\phantom{0}0.59$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.11$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$99.99$ / $\phantom{0}0.37$</td>
#       <td>$99.98$ / $\phantom{0}0.59$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.13$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.39$</td>
#       <td>$99.99$ / $\phantom{0}0.59$</td>
#       <td>$99.99$ / $\phantom{0}0.28$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#       <td>$99.99$ / $\phantom{0}0.41$</td>
#       <td>$99.99$ / $\phantom{0}0.29$</td>
#       <td>$100.00$ / $\phantom{0}0.24$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.27$</td>
#       <td>$99.97$ / $\phantom{0}0.61$</td>
#       <td>$99.99$ / $\phantom{0}0.23$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$100.00$ / $\phantom{0}0.03$</td>
#       <td>$99.98$ / $\phantom{0}0.53$</td>
#       <td>$99.99$ / $\phantom{0}0.36$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat_con_loss_feat_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.06$</td>
#       <td>$99.98$ / $\phantom{0}0.47$</td>
#       <td>$99.99$ / $\phantom{0}0.29$</td>
#       <td>$99.99$ / $\phantom{0}0.22$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat_con_loss_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#       <td>$100.00$ / $\phantom{0}0.03$</td>
#       <td>$99.99$ / $\phantom{0}0.53$</td>
#       <td>$99.99$ / $\phantom{0}0.32$</td>
#       <td>$100.00$ / $\phantom{0}0.24$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_con_loss_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.17$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.47$</td>
#       <td>$99.99$ / $\phantom{0}0.30$</td>
#       <td>$99.99$ / $\phantom{0}0.23$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat_con_loss_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$100.00$ / $\phantom{0}0.03$</td>
#       <td>$99.99$ / $\phantom{0}0.53$</td>
#       <td>$99.99$ / $\phantom{0}0.36$</td>
#       <td>$99.99$ / $\phantom{0}0.27$</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Cross method

# %%
V = 0
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_method_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    tasks=["LibriSeVoc_cross_method", "wavefake_cross_method"],
)
# data = display_cross_method_evaluation(
#     models=models,
#     versions=versions,
#     show_latex=0,
#     tasks=["wavefake_cross_method"],
# )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>dataset</th>
#       <th colspan="5" halign="left">LibriSeVoc</th>
#       <th colspan="7" halign="left">wavefake</th>
#     </tr>
#     <tr>
#       <th>method</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>5</th>
#       <th>999</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>999</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.38$ / $\phantom{0}3.81$</td>
#       <td>$86.20$ / $21.92$</td>
#       <td>$92.76$ / $14.54$</td>
#       <td>$99.98$ / $\phantom{0}0.53$</td>
#       <td>$94.58$ / $10.20$</td>
#       <td>$99.95$ / $\phantom{0}0.92$</td>
#       <td>$99.92$ / $\phantom{0}1.23$</td>
#       <td>$99.47$ / $\phantom{0}3.51$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.79$ / $\phantom{0}1.93$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.86$ / $\phantom{0}1.31$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$84.55$ / $23.90$</td>
#       <td>$89.71$ / $18.67$</td>
#       <td>$74.78$ / $31.39$</td>
#       <td>$88.05$ / $20.86$</td>
#       <td>$84.27$ / $23.70$</td>
#       <td>$79.06$ / $28.37$</td>
#       <td>$69.98$ / $35.26$</td>
#       <td>$71.32$ / $34.22$</td>
#       <td>$99.89$ / $\phantom{0}1.27$</td>
#       <td>$93.87$ / $13.49$</td>
#       <td>$88.24$ / $20.13$</td>
#       <td>$83.73$ / $22.12$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$77.57$ / $29.50$</td>
#       <td>$82.11$ / $25.37$</td>
#       <td>$76.87$ / $30.16$</td>
#       <td>$90.59$ / $17.39$</td>
#       <td>$81.78$ / $25.60$</td>
#       <td>$99.75$ / $\phantom{0}2.40$</td>
#       <td>$98.68$ / $\phantom{0}5.95$</td>
#       <td>$96.88$ / $\phantom{0}9.20$</td>
#       <td>$100.00$ / $\phantom{0}0.11$</td>
#       <td>$99.86$ / $\phantom{0}1.68$</td>
#       <td>$99.90$ / $\phantom{0}1.26$</td>
#       <td>$99.18$ / $\phantom{0}3.43$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$95.54$ / $11.52$</td>
#       <td>$99.06$ / $\phantom{0}4.33$</td>
#       <td>$84.82$ / $23.48$</td>
#       <td>$91.28$ / $16.74$</td>
#       <td>$92.67$ / $14.01$</td>
#       <td>$79.70$ / $27.82$</td>
#       <td>$71.57$ / $34.18$</td>
#       <td>$68.78$ / $35.95$</td>
#       <td>$99.95$ / $\phantom{0}0.73$</td>
#       <td>$97.65$ / $\phantom{0}8.21$</td>
#       <td>$99.87$ / $\phantom{0}1.38$</td>
#       <td>$86.25$ / $18.04$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$92.65$ / $14.86$</td>
#       <td>$97.72$ / $\phantom{0}7.61$</td>
#       <td>$81.68$ / $26.01$</td>
#       <td>$89.78$ / $17.99$</td>
#       <td>$90.46$ / $16.62$</td>
#       <td>$83.79$ / $24.15$</td>
#       <td>$75.20$ / $31.68$</td>
#       <td>$76.19$ / $31.02$</td>
#       <td>$99.98$ / $\phantom{0}0.57$</td>
#       <td>$99.46$ / $\phantom{0}3.32$</td>
#       <td>$99.90$ / $\phantom{0}1.23$</td>
#       <td>$89.09$ / $15.33$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$85.15$ / $22.15$</td>
#       <td>$90.84$ / $16.91$</td>
#       <td>$73.76$ / $31.54$</td>
#       <td>$88.19$ / $19.50$</td>
#       <td>$84.48$ / $22.52$</td>
#       <td>$87.41$ / $21.22$</td>
#       <td>$69.95$ / $35.33$</td>
#       <td>$79.44$ / $27.89$</td>
#       <td>$99.97$ / $\phantom{0}0.61$</td>
#       <td>$95.55$ / $11.34$</td>
#       <td>$95.32$ / $12.04$</td>
#       <td>$87.94$ / $18.07$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$92.77$ / $15.30$</td>
#       <td>$92.05$ / $15.75$</td>
#       <td>$77.04$ / $28.97$</td>
#       <td>$97.62$ / $\phantom{0}8.48$</td>
#       <td>$89.87$ / $17.12$</td>
#       <td>$99.94$ / $\phantom{0}1.13$</td>
#       <td>$99.81$ / $\phantom{0}2.05$</td>
#       <td>$99.43$ / $\phantom{0}3.66$</td>
#       <td>$99.98$ / $\phantom{0}0.78$</td>
#       <td>$98.53$ / $\phantom{0}6.17$</td>
#       <td>$99.98$ / $\phantom{0}0.65$</td>
#       <td>$99.61$ / $\phantom{0}2.40$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$94.10$ / $12.57$</td>
#       <td>$75.71$ / $30.63$</td>
#       <td>$90.18$ / $17.46$</td>
#       <td>$77.33$ / $28.47$</td>
#       <td>$84.33$ / $22.28$</td>
#       <td>$99.94$ / $\phantom{0}0.95$</td>
#       <td>$99.97$ / $\phantom{0}0.63$</td>
#       <td>$99.43$ / $\phantom{0}3.51$</td>
#       <td>$100.00$ / $\phantom{0}0.23$</td>
#       <td>$99.95$ / $\phantom{0}0.90$</td>
#       <td>$99.99$ / $\phantom{0}0.56$</td>
#       <td>$99.88$ / $\phantom{0}1.13$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$91.02$ / $16.74$</td>
#       <td>$86.63$ / $20.83$</td>
#       <td>$80.32$ / $27.04$</td>
#       <td>$97.29$ / $\phantom{0}8.25$</td>
#       <td>$88.82$ / $18.21$</td>
#       <td>$99.71$ / $\phantom{0}2.45$</td>
#       <td>$96.62$ / $\phantom{0}9.97$</td>
#       <td>$96.10$ / $10.62$</td>
#       <td>$99.99$ / $\phantom{0}0.34$</td>
#       <td>$99.96$ / $\phantom{0}0.88$</td>
#       <td>$99.97$ / $\phantom{0}0.76$</td>
#       <td>$98.73$ / $\phantom{0}4.17$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$99.05$ / $\phantom{0}4.20$</td>
#       <td>$97.56$ / $\phantom{0}7.11$</td>
#       <td>$87.82$ / $18.67$</td>
#       <td>$99.79$ / $\phantom{0}2.20$</td>
#       <td>$96.05$ / $\phantom{0}8.04$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.11$</td>
#       <td>$99.97$ / $\phantom{0}0.73$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.02$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.16$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$97.25$ / $\phantom{0}7.57$</td>
#       <td>$95.68$ / $\phantom{0}9.66$</td>
#       <td>$84.21$ / $22.27$</td>
#       <td>$99.59$ / $\phantom{0}2.89$</td>
#       <td>$94.18$ / $10.60$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.42$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$98.24$ / $\phantom{0}6.13$</td>
#       <td>$91.54$ / $16.32$</td>
#       <td>$64.05$ / $40.83$</td>
#       <td>$99.77$ / $\phantom{0}1.83$</td>
#       <td>$88.40$ / $16.28$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.40$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$98.11$ / $\phantom{0}6.63$</td>
#       <td>$92.55$ / $14.92$</td>
#       <td>$71.96$ / $34.15$</td>
#       <td>$99.83$ / $\phantom{0}1.81$</td>
#       <td>$90.61$ / $14.38$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.99$ / $\phantom{0}0.44$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$96.25$ / $\phantom{0}8.64$</td>
#       <td>$89.96$ / $15.75$</td>
#       <td>$83.07$ / $24.37$</td>
#       <td>$99.61$ / $\phantom{0}2.99$</td>
#       <td>$92.22$ / $12.94$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.15$</td>
#       <td>$99.97$ / $\phantom{0}0.73$</td>
#       <td>$100.00$ / $\phantom{0}0.04$</td>
#       <td>$100.00$ / $\phantom{0}0.01$</td>
#       <td>$100.00$ / $\phantom{0}0.00$</td>
#       <td>$99.99$ / $\phantom{0}0.16$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>

# %% [markdown]
# ## Cross Dataset

# %%
V = 1
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

data = display_cross_dataset_evaluation(
    models=models,
    versions=versions,
    show_latex=0,
    tasks=[
        "LibriSeVoc_cross_dataset",
        # "DECRO_chinese",
        # "DECRO_english",
    ],
    only_LibriSeVoc=False,
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>avg</th>
#       <th>ch</th>
#       <th>en</th>
#       <th>inTheWild</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$100.00$ / $\phantom{0}0.14$</td>
#       <td>$95.00$ / $12.30$</td>
#       <td>$96.27$ / $10.36$</td>
#       <td>$96.87$ / $\phantom{0}9.40$</td>
#       <td>$97.03$ / $\phantom{0}9.12$</td>
#       <td>$100.00$ / $\phantom{0}0.09$</td>
#       <td>$99.98$ / $\phantom{0}0.53$</td>
#       <td>$97.88$ / $\phantom{0}5.99$</td>
#       <td>$79.70$ / $26.63$</td>
#       <td>$63.56$ / $40.36$</td>
#       <td>$41.19$ / $57.63$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$99.72$ / $\phantom{0}2.33$</td>
#       <td>$79.98$ / $27.74$</td>
#       <td>$89.97$ / $18.60$</td>
#       <td>$69.27$ / $36.15$</td>
#       <td>$79.50$ / $28.11$</td>
#       <td>$97.27$ / $\phantom{0}8.55$</td>
#       <td>$99.98$ / $\phantom{0}0.61$</td>
#       <td>$87.95$ / $17.44$</td>
#       <td>$64.68$ / $39.65$</td>
#       <td>$45.59$ / $53.70$</td>
#       <td>$88.92$ / $19.83$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$100.00$ / $\phantom{0}0.16$</td>
#       <td>$88.57$ / $19.90$</td>
#       <td>$98.56$ / $\phantom{0}6.13$</td>
#       <td>$87.74$ / $20.55$</td>
#       <td>$87.61$ / $20.65$</td>
#       <td>$99.88$ / $\phantom{0}1.34$</td>
#       <td>$100.00$ / $\phantom{0}0.20$</td>
#       <td>$94.62$ / $\phantom{0}9.85$</td>
#       <td>$75.34$ / $33.05$</td>
#       <td>$76.88$ / $30.07$</td>
#       <td>$94.16$ / $12.78$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$93.54$ / $14.24$</td>
#       <td>$73.00$ / $33.05$</td>
#       <td>$82.42$ / $25.56$</td>
#       <td>$64.59$ / $39.51$</td>
#       <td>$73.72$ / $32.56$</td>
#       <td>$83.82$ / $24.06$</td>
#       <td>$99.64$ / $\phantom{0}2.82$</td>
#       <td>$81.53$ / $24.55$</td>
#       <td>$82.45$ / $25.78$</td>
#       <td>$90.51$ / $17.49$</td>
#       <td>$88.09$ / $20.55$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$96.14$ / $10.58$</td>
#       <td>$65.86$ / $38.56$</td>
#       <td>$83.04$ / $24.98$</td>
#       <td>$62.32$ / $41.18$</td>
#       <td>$73.03$ / $33.09$</td>
#       <td>$85.24$ / $22.87$</td>
#       <td>$99.91$ / $\phantom{0}1.35$</td>
#       <td>$80.79$ / $24.66$</td>
#       <td>$78.71$ / $29.60$</td>
#       <td>$89.20$ / $18.34$</td>
#       <td>$90.24$ / $17.50$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$99.73$ / $\phantom{0}2.19$</td>
#       <td>$76.05$ / $30.42$</td>
#       <td>$89.35$ / $18.39$</td>
#       <td>$68.04$ / $36.34$</td>
#       <td>$78.75$ / $28.21$</td>
#       <td>$98.53$ / $\phantom{0}6.03$</td>
#       <td>$99.96$ / $\phantom{0}0.91$</td>
#       <td>$87.20$ / $17.50$</td>
#       <td>$70.14$ / $35.51$</td>
#       <td>$48.73$ / $51.15$</td>
#       <td>$89.84$ / $18.05$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$99.38$ / $\phantom{0}2.97$</td>
#       <td>$81.51$ / $25.02$</td>
#       <td>$97.45$ / $\phantom{0}6.02$</td>
#       <td>$90.17$ / $15.54$</td>
#       <td>$93.73$ / $10.94$</td>
#       <td>$99.08$ / $\phantom{0}3.55$</td>
#       <td>$99.15$ / $\phantom{0}3.57$</td>
#       <td>$94.35$ / $\phantom{0}9.66$</td>
#       <td>$69.20$ / $35.93$</td>
#       <td>$70.56$ / $32.30$</td>
#       <td>$69.88$ / $35.93$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$99.99$ / $\phantom{0}0.39$</td>
#       <td>$96.02$ / $10.79$</td>
#       <td>$99.70$ / $\phantom{0}2.48$</td>
#       <td>$98.58$ / $\phantom{0}5.97$</td>
#       <td>$98.92$ / $\phantom{0}5.02$</td>
#       <td>$99.91$ / $\phantom{0}1.31$</td>
#       <td>$100.00$ / $\phantom{0}0.18$</td>
#       <td>$99.02$ / $\phantom{0}3.73$</td>
#       <td>$85.78$ / $21.69$</td>
#       <td>$73.25$ / $33.53$</td>
#       <td>$29.53$ / $66.58$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$91.56$ / $16.56$</td>
#       <td>$98.72$ / $\phantom{0}5.64$</td>
#       <td>$90.12$ / $18.25$</td>
#       <td>$91.22$ / $17.11$</td>
#       <td>$100.00$ / $\phantom{0}0.16$</td>
#       <td>$99.99$ / $\phantom{0}0.40$</td>
#       <td>$95.94$ / $\phantom{0}8.31$</td>
#       <td>$84.50$ / $24.64$</td>
#       <td>$76.13$ / $31.99$</td>
#       <td>$95.15$ / $12.37$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.38$ / $\phantom{0}3.80$</td>
#       <td>$97.19$ / $\phantom{0}8.89$</td>
#       <td>$99.20$ / $\phantom{0}4.34$</td>
#       <td>$99.00$ / $\phantom{0}5.05$</td>
#       <td>$99.99$ / $\phantom{0}0.34$</td>
#       <td>$100.00$ / $\phantom{0}0.14$</td>
#       <td>$99.25$ / $\phantom{0}3.23$</td>
#       <td>$84.83$ / $21.21$</td>
#       <td>$98.90$ / $\phantom{0}4.35$</td>
#       <td>$42.63$ / $58.01$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.07$</td>
#       <td>$99.18$ / $\phantom{0}4.35$</td>
#       <td>$98.74$ / $\phantom{0}5.55$</td>
#       <td>$99.33$ / $\phantom{0}3.95$</td>
#       <td>$99.25$ / $\phantom{0}4.05$</td>
#       <td>$99.99$ / $\phantom{0}0.17$</td>
#       <td>$100.00$ / $\phantom{0}0.11$</td>
#       <td>$99.50$ / $\phantom{0}2.61$</td>
#       <td>$87.81$ / $19.40$</td>
#       <td>$96.78$ / $\phantom{0}9.05$</td>
#       <td>$40.30$ / $58.79$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.08$</td>
#       <td>$99.46$ / $\phantom{0}3.53$</td>
#       <td>$99.43$ / $\phantom{0}3.74$</td>
#       <td>$99.55$ / $\phantom{0}3.22$</td>
#       <td>$99.44$ / $\phantom{0}3.56$</td>
#       <td>$99.99$ / $\phantom{0}0.32$</td>
#       <td>$100.00$ / $\phantom{0}0.02$</td>
#       <td>$99.70$ / $\phantom{0}2.07$</td>
#       <td>$86.47$ / $20.40$</td>
#       <td>$99.16$ / $\phantom{0}4.14$</td>
#       <td>$49.03$ / $51.54$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$99.51$ / $\phantom{0}3.37$</td>
#       <td>$98.39$ / $\phantom{0}6.39$</td>
#       <td>$99.44$ / $\phantom{0}3.61$</td>
#       <td>$99.36$ / $\phantom{0}3.84$</td>
#       <td>$99.99$ / $\phantom{0}0.17$</td>
#       <td>$100.00$ / $\phantom{0}0.10$</td>
#       <td>$99.53$ / $\phantom{0}2.50$</td>
#       <td>$86.58$ / $19.76$</td>
#       <td>$99.12$ / $\phantom{0}4.55$</td>
#       <td>$46.62$ / $53.41$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$99.97$ / $\phantom{0}0.57$</td>
#       <td>$95.34$ / $11.65$</td>
#       <td>$91.92$ / $15.61$</td>
#       <td>$92.83$ / $14.73$</td>
#       <td>$93.16$ / $14.37$</td>
#       <td>$99.75$ / $\phantom{0}1.89$</td>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$96.14$ / $\phantom{0}8.41$</td>
#       <td>$78.96$ / $26.80$</td>
#       <td>$87.18$ / $18.97$</td>
#       <td>$55.04$ / $46.63$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$100.00$ / $\phantom{0}0.05$</td>
#       <td>$99.45$ / $\phantom{0}3.60$</td>
#       <td>$96.13$ / $10.67$</td>
#       <td>$99.33$ / $\phantom{0}3.98$</td>
#       <td>$98.79$ / $\phantom{0}5.51$</td>
#       <td>$100.00$ / $\phantom{0}0.19$</td>
#       <td>$100.00$ / $\phantom{0}0.17$</td>
#       <td>$99.10$ / $\phantom{0}3.45$</td>
#       <td>$87.85$ / $18.37$</td>
#       <td>$99.53$ / $\phantom{0}3.03$</td>
#       <td>$41.44$ / $58.87$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$99.78$ / $\phantom{0}1.68$</td>
#       <td>$88.45$ / $19.71$</td>
#       <td>$82.97$ / $24.85$</td>
#       <td>$86.30$ / $21.73$</td>
#       <td>$85.07$ / $23.17$</td>
#       <td>$99.64$ / $\phantom{0}2.47$</td>
#       <td>$99.70$ / $\phantom{0}1.14$</td>
#       <td>$91.70$ / $13.54$</td>
#       <t

# %% [markdown]
# ## Cross Language

# %%
V = 1
MODELs_VERSIONS.update(
    {
        "Ours/ResNet": 0,
        # "Ours/ablations/op_loss/ResNet":V,
        # "Ours/ablations/policy_ld/ResNet":V,
        # "Ours/ablations/policy_ay/ResNet":V,
    }
)
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()
data = display_cross_language_evaluation(
    models=models, versions=versions, show_latex=0, auc=1
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>wavefake_cross_lang</th>
#       <th>DECRO_chinese</th>
#       <th>DECRO_english</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$99.63$ / $\phantom{0}2.90$</td>
#       <td>$53.60$ / $43.62$</td>
#       <td>$68.30$ / $36.46$</td>
#       <td>$73.85$ / $27.66$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$72.70$ / $33.69$</td>
#       <td>$50.66$ / $47.08$</td>
#       <td>$53.93$ / $47.80$</td>
#       <td>$59.09$ / $42.86$</td>
#     </tr>
#     <tr>
#       <th>RawGAT</th>
#       <td>$93.49$ / $14.39$</td>
#       <td>$57.11$ / $41.14$</td>
#       <td>$55.07$ / $47.88$</td>
#       <td>$68.56$ / $34.47$</td>
#     </tr>
#     <tr>
#       <th>Wave2Vec2</th>
#       <td>$86.89$ / $21.58$</td>
#       <td>$34.89$ / $61.40$</td>
#       <td>$52.75$ / $46.57$</td>
#       <td>$58.18$ / $43.18$</td>
#     </tr>
#     <tr>
#       <th>WaveLM</th>
#       <td>$83.91$ / $24.50$</td>
#       <td>$36.20$ / $59.03$</td>
#       <td>$53.84$ / $45.65$</td>
#       <td>$57.98$ / $43.06$</td>
#     </tr>
#     <tr>
#       <th>LibriSeVoc</th>
#       <td>$74.10$ / $32.94$</td>
#       <td>$63.21$ / $41.33$</td>
#       <td>$56.35$ / $46.58$</td>
#       <td>$64.55$ / $40.28$</td>
#     </tr>
#     <tr>
#       <th>AudioClip</th>
#       <td>$46.98$ / $52.54$</td>
#       <td>$55.67$ / $46.40$</td>
#       <td>$48.95$ / $52.10$</td>
#       <td>$50.53$ / $50.35$</td>
#     </tr>
#     <tr>
#       <th>Wav2Clip</th>
#       <td>$84.19$ / $23.88$</td>
#       <td>$72.22$ / $37.07$</td>
#       <td>$84.48$ / $22.75$</td>
#       <td>$80.30$ / $27.90$</td>
#     </tr>
#     <tr>
#       <th>AASIST</th>
#       <td>$95.24$ / $11.78$</td>
#       <td>$59.67$ / $41.49$</td>
#       <td>$55.95$ / $46.34$</td>
#       <td>$70.29$ / $33.20$</td>
#     </tr>
#     <tr>
#       <th>Ours/ResNet</th>
#       <td>$87.76$ / $20.08$</td>
#       <td>$93.31$ / $15.82$</td>
#       <td>$73.57$ / $33.49$</td>
#       <td>$84.88$ / $23.13$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat/ResNet</th>
#       <td>$89.13$ / $18.75$</td>
#       <td>$96.45$ / $\phantom{0}9.06$</td>
#       <td>$75.34$ / $33.26$</td>
#       <td>$86.97$ / $20.36$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_voc/ResNet</th>
#       <td>$89.53$ / $18.28$</td>
#       <td>$97.05$ / $\phantom{0}7.37$</td>
#       <td>$77.15$ / $31.06$</td>
#       <td>$87.91$ / $18.90$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/con_loss_feat_voc/ResNet</th>
#       <td>$88.99$ / $18.97$</td>
#       <td>$97.05$ / $\phantom{0}7.64$</td>
#       <td>$73.80$ / $34.07$</td>
#       <td>$86.61$ / $20.23$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat/ResNet</th>
#       <td>$89.74$ / $18.18$</td>
#       <td>$90.38$ / $18.81$</td>
#       <td>$79.81$ / $28.89$</td>
#       <td>$86.64$ / $21.96$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style/ResNet</th>
#       <td>$89.87$ / $17.98$</td>
#       <td>$86.27$ / $27.73$</td>
#       <td>$77.87$ / $29.56$</td>
#       <td>$84.67$ / $25.09$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat/ResNet</th>
#       <td>$89.73$ / $18.29$</td>
#       <td>$88.58$ / $23.31$</td>
#       <td>$77.79$ / $30.16$</td>
#       <td>$85.36$ / $23.92$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat_con_loss_feat_voc/ResNet</th>
#       <td>$88.39$ / $19.50$</td>
#       <td>$87.80$ / $25.64$</td>
#       <td>$79.02$ / $29.09$</td>
#       <td>$85.07$ / $24.74$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_feat_con_loss_voc/ResNet</th>
#       <td>$87.51$ / $19.94$</td>
#       <td>$90.56$ / $21.60$</td>
#       <td>$81.64$ / $26.52$</td>
#       <td>$86.57$ / $22.69$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_con_loss_voc/ResNet</th>
#       <td>$90.15$ / $17.48$</td>
#       <td>$93.97$ / $13.68$</td>
#       <td>$72.36$ / $34.14$</td>
#       <td>$85.49$ / $21.77$</td>
#     </tr>
#     <tr>
#       <th>Ours/ablations/shuffle_style_feat_con_loss_voc/ResNet</th>
#       <td>$91.20$ / $16.28$</td>
#       <td>$89.94$ / $23.27$</td>
#       <td>$85.40$ / $22.69$</td>
#       <td>$88.85$ / $20.75$</td>
#     </tr>
#   </tbody>
# </table>
