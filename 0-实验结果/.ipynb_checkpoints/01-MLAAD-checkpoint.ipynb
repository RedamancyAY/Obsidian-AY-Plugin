# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from IPython.display import HTML, display

# %%
from ay2.datasets.audio import MLAAD_AudioDs

ds = MLAAD_AudioDs(root_path=MLAAD_AudioDs.default_root_path)
test_keys = ds.get_splits().test_keys + ["in_the_wild", "DECRO-en", "DECRO-cn"]

# %%
test_keys = ds.get_splits(language_list=["de", "es", "ru"]).test_keys + ["in_the_wild", "DECRO-en", "DECRO-cn"]

# %%
ds.get_splits(language_list=[]).test_keys + ["in_the_wild", "DECRO-en", "DECRO-cn"]

# %%
from utils import BaseDisplay, Display_MLAAD_evaluation

# %%
MODELs_VERSIONS = {
    "LCNN": 1,
    "RawNet2": 0,
    "RawGAT": 0,
    "Wave2Vec2": 0,
    "WaveLM": 0,
    "LibriSeVoc": 0,
    "AudioClip": 0,
    "Wav2Clip": 0,
    "AASIST": 0,
    "MPE_LCNN": 0,
    "ABCNet": 0,
    "ASDG":5,
    "MultiViewCombine/ablations/aasist_LCNN": 0,
    "MultiViewCombine/ablations/aasist_resnet": 0,
    "MultiViewCombine/ablations/rawnet_LCNN": 0,
    "MultiViewCombine/ablations/rawnet_resnet": 0,
    # "Ours/ResNet": 0,
    # "OursLCNN": 9,
    "OursPhonemeGAT": 3,
    # "OursPhonemeGAT/ablations/use_aug": range(17, 26),
    # "OursPhonemeGAT/ablations/use_aug_no_GAT":  range(12),
    # "OursPhonemeGAT/ablations/no_GAT":  range(12),
}
models = MODELs_VERSIONS.keys()
versions = MODELs_VERSIONS.values()

res = Display_MLAAD_evaluation(models, versions, task="MLAAD_cross_lang", auc=1, acc=0, calc_avg=False)
res.display(show_latex=1, drop=['DECRO-en', 'DECRO-cn'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>method</th>
#       <th>full</th>
#       <th>fr</th>
#       <th>it</th>
#       <th>pl</th>
#       <th>ru</th>
#       <th>uk</th>
#       <th>in_the_wild</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LCNN</th>
#       <td>$96.27$ / $\phantom{0}9.42$</td>
#       <td>$98.69$ / $\phantom{0}6.12$</td>
#       <td>$97.24$ / $\phantom{0}9.57$</td>
#       <td>$99.70$ / $\phantom{0}2.50$</td>
#       <td>$89.42$ / $19.08$</td>
#       <td>$98.50$ / $\phantom{0}5.94$</td>
#       <td>$30.49$ / $64.08$</td>
#     </tr>
#     <tr>
#       <th>RawNet2</th>
#       <td>$85.52$ / $22.71$</td>
#       <td>$86.19$ / $21.08$</td>
#       <td>$83.97$ / $24.00$</td>
#       <td>$94.49$ / $13.16$</td>
# ...

# %%
res = Display_MLAAD_evaluation(models, versions, task="MLAAD_de_es_ru", auc=0, acc=1, calc_avg=False, late_read=True)
res.set_Columns(["full", "en", "fr", "it", "pl", "uk", "in_the_wild", "DECRO-en", "DECRO-cn"])
res.display(show_latex=0)

# %%
res = Display_MLAAD_evaluation(models, versions, task="MLAAD_DECRO", auc=0, acc=1, calc_avg=False, late_read=True)
res.set_Columns(["full", 'de', "en", 'es', "fr", "it", "pl", 'ru', "uk", "in_the_wild", "DECRO-en", "DECRO-cn"])
res.display(show_latex=0)

# %% [markdown]
# ## Ablations

# %%
from utils import (
    Display_ASV2019_LA_evaluation,
    Display_ASV2021_evaluation,
    Display_ASV2021_LA_evaluation,
)

# %%
MODELs_VERSIONS = {
    "Wave2Vec2": range(3),
    "WaveLM": range(3),
    "OursPhonemeGAT/ablations/no_pool_no_clip_use_raw": range(3),
    "OursPhonemeGAT/ablations/no_pool_no_clip_use_raw_wav2vec": range(3),
    "OursPhonemeGAT/ablations/no_pool_no_clip": range(3),
    "OursPhonemeGAT/ablations/no_GAT": range(3),
    "OursPhonemeGAT/ablations/no_aug_no_GAT": range(3),
    "OursPhonemeGAT/ablations/no_pool": range(3),
    "OursPhonemeGAT/ablations/no_clip": range(3),
    "OursPhonemeGAT/ablations/no_aug": range(3),
    "OursPhonemeGAT/ablations/wav2vec": range(3),
    "OursPhonemeGAT/ablations/edges0": range(3),
    "OursPhonemeGAT/ablations/edges2": range(3),
    "OursPhonemeGAT/ablations/edges4": range(3),
    "OursPhonemeGAT/ablations/edges6": range(3),
    "OursPhonemeGAT/ablations/edges8": range(3),
    "OursPhonemeGAT/ablations/edges12": range(3),
    "OursPhonemeGAT/ablations/edges14": range(3),
    "OursPhonemeGAT/ablations/edges16": range(3),
    "OursPhonemeGAT/ablations/edges18": range(3),
}
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", auc=1, acc=0, calc_avg=False
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/ASV2021_inner/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/WaveLM/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/WaveLM/ASV2021_inner/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ablations/no_pool_no_clip_use_raw/ASV2021_inner/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ablations/no_pool_no_clip_use_raw/ASV2021_inner/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ablations/no_pool_no_clip_use_raw/ASV2021_inner/version_2/test.csv
# ...

# %%
res = Display_ASV2021_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", auc=1, acc=0, calc_avg=True
)
res.display(show_latex=0)

# %%
res = Display_ASV2019_LA_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2019_LA", auc=1, acc=0, calc_avg=False
)
res.display(show_latex=0)

# %%
res = Display_ASV2021_evaluation(
    models=MODELs_VERSIONS.keys(), versions=MODELs_VERSIONS.values(), task="ASV2021_inner", auc=0, acc=0, calc_avg=False, file_name="noise_bg_20"
)
res.display(show_latex=1)

# %%
res = Display_MLAAD_evaluation(
    models=MODELs_VERSIONS.keys(),
    versions=MODELs_VERSIONS.values(),
    task="MLAAD_cross_lang",
    auc=0,
    acc=1,
    calc_avg=False,
)
res.display(show_latex=0)
# Out:
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/MLAAD_cross_lang/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/Wave2Vec2/MLAAD_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/WaveLM/MLAAD_cross_lang/version_1/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/WaveLM/MLAAD_cross_lang/version_2/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ablations/no_pool_no_clip_use_raw/MLAAD_cross_lang/version_0/test.csv
# Warning!!!! cannot find:  /home/ay/data/DATA/1-model_save/00-Deepfake/1-df-audio/OursPhonemeGAT/ablations/no_pool_no_clip_use_raw/MLAAD_cross_lang/version_1/test.csv
# ...
